# %%
## Loading libs:
import pandas as pd
import matplotlib.pyplot as plt
import numpy as  np
from scipy import signal
import scipy
import ipywidgets as widgets
from ipywidgets import interact, interact_manual
from ipywidgets import interactive
from IPython.display import HTML
import math
import datetime
from matplotlib import animation
import pickle
##load the csv file containing the data
data_path = "..\\Datasets\\Forecasting_aqua\\ctd_meteo_aua_2019to2021_V2.csv"
df = pd.read_csv(data_path)

#make the date a date object
format = "%d-%m-%Y"
time_df = pd.to_datetime(df["Datetime"], format=format)
df['Datetime']= time_df

#drop a useless column
df.drop("sample",axis=1,inplace=True,errors='ignore')

#add year, month and day from datetime
df['year'] = df['Datetime'].dt.year
df['month'] = df['Datetime'].dt.month
df['day'] = df['Datetime'].dt.day


#prepare the tickslabels
years = df['year'].unique()
months=[]
fday = []
for day in range(1,366):
    dstr = str(day)
    date = datetime.datetime.strptime("2019-" + dstr, "%Y-%j")
    months.append(date.strftime("%b"))
months,fday = np.unique(months,return_index=True)
#note that the months are not in order, but the ticks are still correct


print("You have now loaded the libraries and the data")
# Out:
# You have now loaded the libraries and the data

# %%
taxa_keys = ['asplanchna', 'asterionella', 'brachionus', 'diatom_chain', 'dinobryon',
       'eudiaptomus', 'kellikottia', 'keratella_quadrata', 'nauplius',
       'polyarthra', 'rotifers', 'synchaeta', 'ceratium', 'cyclops',
       'fragilaria', 'keratella_cochlearis', 'paradileptus', 'bosmina',
       'daphnia', 'trichocerca', 'conochilus', 'diaphanosoma', 'uroglena',
       'leptodora', 'chaoborus', 'aphanizomenon','diatom','ciliate']
cluster_keys = ['cluster_1', 'cluster_2','cluster_3', 'cluster_4', 'cluster_5', 'cluster_6', 'cluster_7',
               'cluster_8']
water_keys = ['mean_temp', 'cv_temp_day','cv_temp_depth', 'mean_condF', 'cv_condF_day', 'cv_condF_depth',
       'mean_o2', 'cv_o2_day', 'cv_o2_depth', 'mean_o2ppm', 'cv_o2ppm_day',
       'cv_o2ppm_depth', 'mean_ph', 'cv_ph_day', 'cv_ph_depth', 'mean_chla',
       'cv_chla_day', 'cv_chla_depth', 'mean_turb', 'cv_turb_day',
       'cv_turb_depth', 'mean_par', 'cv_par_day', 'cv_par_depth']
meteo_keys = ['mean_cloud_cover', 'mean_global_radiation', 'atmospheric_pressure_max',
       'atmospheric_pressure_min', 'atmospheric_pressure_mean', 'temp_max',
       'temp_min', 'temp_mean', 'precipitation_tot', 'rel_air_humidity_max',
       'rel_air_humidity_min', 'rel_air_humidity_mean', 'sunshine_duration',
       'windspeed_mean', 'windspeed_max', 'wind_direction_mean']
nut_keys = ['Nitrat','Nitrit', 'Ammonium', 'oP', 'TP', 'TN',]
phys_keys = ['mean_thermocline_depth',
       'cv_thermo', 'mean_schmidt', 'cv_schmidt', 'mean_epi_temp',
       'cv_epi_temp', 'mean_mixed_layer_depth', 'cv_mixed_layer_depth',
       'ml_irradiance', 'mean_oxycline_depth', 'cv_oxycline_depth']
temporal_key = ['year','month', 'day']

# %%
#interpolate
dfi = df.interpolate(method='ffill', axis=0)
#the following columns were not used during the whole duration of the experiment
dfi.drop(columns=['mean_phy','cv_phy_day','cv_phy_depth','mean_phycoer','cv_phycoer_day',
                  'cv_phycoer_depth','TOC'],
         inplace=True,errors='ignore')
#only use valid values
dfi.dropna(inplace=True)
dfi.reset_index(inplace=True,drop=True)
dfi.drop(columns=['Datetime'],inplace=True, errors='ignore')

# %%
#shorten the dataset:
dfs = dfi[30:120]
dfs = dfs[taxa_keys]

# %%
dfs
# Out:
#      asplanchna  asterionella  brachionus  diatom_chain  dinobryon  \
# 30     0.000972      0.000972    0.003194      0.001250   0.009375
# 31     0.000347      0.001389    0.001528      0.001528   0.008125
# 32     0.000556      0.000625    0.001319      0.001319   0.005625
# 33     0.000486      0.000694    0.000833      0.001042   0.003125
# 34     0.000625      0.000694    0.001319      0.000486   0.002222
# ..          ...           ...         ...           ...        ...
# 115    0.000000      0.000000    0.000000      0.000000   0.011667
# 116    0.000000      0.000000    0.000000      0.000000   0.121667
# 117    0.000000      0.000000    0.000000      0.000000   0.121667
# 118    0.000530      0.000455    0.003333      0.000152   0.586515
# 119    0.000764      0.001250    0.006528      0.000000   0.944444
#
#      eudiaptomus  kellikottia  keratella_quadrata  nauplius  polyarthra  ...  \
# 30      0.010625     0.004444            0.000625  0.051597    0.000486  ...
# 31      0.007083     0.002639            0.000278  0.041667    0.000208  ...
# 32      0.012014     0.003125            0.000625  0.040347    0.000556  ...
# 33      0.018542     0.004028            0.000625  0.041944    0.000069  ...
# 34      0.011389     0.005278            0.000278  0.047917    0.000278  ...
# ..           ...          ...                 ...       ...         ...  ...
# 115     0.000000     0.000000            0.001667  0.003333    0.000000  ...
# 116     0.006667     0.000000            0.000000  0.005000    0.000000  ...
# 117     0.006667     0.000000            0.000000  0.005000    0.000000  ...
# 118     0.007803     0.000833            0.002955  0.026288    0.000227  ...
# 119     0.010139     0.000903            0.003750  0.038333    0.000278  ...
#
#       daphnia  trichocerca  conochilus  diaphanosoma  uroglena  leptodora  \
# 30   0.003264     0.000208    0.004514      0.000000  0.000278   0.000000
# 31   0.006319     0.000208    0.003542      0.000139  0.000139   0.000000
# 32   0.002639     0.000347    0.003125      0.000069  0.000278   0.000000
# 33   0.008611     0.000347    0.004236      0.000208  0.000208   0.000139
# 34   0.002917     0.000208    0.005208      0.000208  0.000139   0.000069
# ..        ...          ...         ...           ...       ...        ...
# 115  0.000000     0.001667    0.000000      0.000000  0.001667   0.000000
# 116  0.000000     0.000000    0.000000      0.000000  0.020000   0.000000
# 117  0.000000     0.000000    0.000000      0.000000  0.020000   0.000000
# 118  0.005833     0.004394    0.000152      0.004091  0.092273   0.000152
# 119  0.006806     0.004722    0.000139      0.004583  0.186736   0.000347
#
#      chaoborus  aphanizomenon    diatom   ciliate
# 30    0.000000       0.000764  0.011667  0.001061
# 31    0.000139       0.000764  0.015217  0.002246
# 32    0.000000       0.000347  0.015556  0.002500
# 33    0.000000       0.000278  0.013478  0.002536
# 34    0.000000       0.000556  0.016232  0.002536
# ..         ...            ...       ...       ...
# 115   0.000000       0.000000  0.000556  0.001111
# 116   0.000000       0.000000  0.005079  0.003651
# 117   0.000000       0.000000  0.003167  0.005333
# 118   0.000076       0.001136  0.005526  0.008158
# 119   0.000000       0.001875  0.007391  0.007464
#
# [90 rows x 28 columns]

# %%
#define the function:
def windowed_cor(df,key1,key2,window_size,max_lag,epsilon=0.00000000001):
    cor = np.zeros((max_lag,len(df)-window_size-max_lag))
    dfd = df.drop('Datetime',axis=1,errors='ignore')
    for start in range(len(df)-window_size-max_lag):
        for lag in range(max_lag):
            input1=dfd[key1][start:start+window_size]
            input1.interpolate(method='linear', limit_direction='forward', axis=0)
            input1=input1-input1.mean()
            input1.reset_index(drop=True,inplace=True)
            input2=dfd[key2][start+lag:start+window_size+lag]
            input2.interpolate(method='linear', limit_direction='forward', axis=0)
            input2=input2-input2.mean()
            input2.reset_index(drop=True,inplace=True)
            
            cor[lag,start] =(input1*input2).mean()/(input1.std()*input2.std()+epsilon)
    return cor

# %%
#test the function
cor = windowed_cor(dfs,'nauplius','nauplius',30,1)

# %%
plt.plot(cor[0])

# %%
#build the time dependant correlation array:
window = 60
cor_a = np.zeros((len(dfs.keys()),len(dfs.keys()),len(dfs)-window-1))
for idx1,key1 in enumerate(dfs.keys()):
    print(f"{idx1}/{len(dfs.keys())}",end='\r')
    for idx2,key2 in enumerate(dfs.keys()[idx1:]):
        idx2+=idx1
        cor_a[idx1,idx2,:]=np.squeeze(windowed_cor(dfs,key1,key2,window,1))
# Out:
# 27/96

# %%
#fill the missing values
cor_af = cor_a + np.transpose(cor_a, axes=[1,0,2])
for i in range(cor_af.shape[0]):
    cor_af[i,i,:]=cor_af[i,i,:]/2

# %%
#for now, focus only on one month of the time serie:
start_date = 28
cor = cor_af[:,:,start_date]

# %%
plt.imshow(cor)

# %%
#compute the partial corelation
def part_cor(cor):
    size = cor.shape[0]
    par_cor = np.zeros((size,size,size))
    icor2 = 1-np.square(cor)
    for i in range(size):
        par_cor[i,:,:]=np.array([(cor[i,k]-cor[k,:]*cor[i,:])/(icor2[i,:]*icor2[k,:]) for k in range(size)])
    return par_cor

par_cor = part_cor(cor)

# %%
plt.imshow(par_cor[:,:,19])

# %%
par_cor[0,0,0]
# Out:
# 14.9981003424533

# %%
d = np.repeat(np.expand_dims(cor,-1),cor.shape[0],axis=2)-par_cor

# %%
size = d.shape[0]
D = np.sum(d,axis=1)
for j in range(size):
    D[:,j] -= d[:,j,j] 
D/=(d.shape[0]-1)

# %%
th = 0.15
Df = np.copy(D)
Df[np.abs(D)<th]=0

# %%
plt.imshow(Df)

# %%
#normalize D:
Dn = (D-np.min(D))/(np.max(D)-np.min(D))
plt.imshow(Dn)

# %%
min_tree = scipy.sparse.csgraph.minimum_spanning_tree(Dn, overwrite=False)

# %%
mta = min_tree.toarray()

# %%
mta.shape
# Out:
# (28, 28)

# %%
from pyvis.network import Network
import networkx as nx

import matplotlib.pyplot as plt

# %%
net = Network(notebook=True,height='600px', width='800px', bgcolor='#222222', font_color='white',
              directed=False,layout=False)
net.barnes_hut()
for idx,key in enumerate(dfs.keys()):
    if key in taxa_keys:
        color = 'lime'
    elif key in cluster_keys: 
        color = 'green'
    elif key in water_keys:
        color = 'blue'
    elif key in meteo_keys:
        color = 'cyan'
    elif key in nut_keys:
        color = 'red'
    elif key in phys_keys:
        color = 'yellow'
    else:
        color = 'purple'
    net.add_node(idx, label=key, shape='dot',color=color)
for idx1 in range(D.shape[0]):
    for idx2 in range(D.shape[0]):
        if mta[idx1,idx2] != 0:
            net.add_edge(idx1,idx2,width=15*mta[idx1,idx2])

# %%
net = Network(height='600px', width='800px', bgcolor='#FFFFFF', font_color='black',
              directed=True,layout=False)
net.barnes_hut()
for idx,key in enumerate(dfs.keys()):
    if key in taxa_keys:
        color = 'lime'
    elif key in cluster_keys: 
        color = 'green'
    elif key in water_keys:
        color = 'blue'
    elif key in meteo_keys:
        color = 'cyan'
    elif key in nut_keys:
        color = 'red'
    elif key in phys_keys:
        color = 'yellow'
    else:
        color = 'purple'
    net.add_node(idx, label=key, shape='dot',color=color)
for idx1 in range(D.shape[0]):
    for idx2 in range(D.shape[0]):
        if idx1 != idx2 and Df[idx1,idx2] != 0:
            if Df[idx1,idx2]<0:
                net.add_edge(idx2,idx1,width=15*np.abs(Df[idx1,idx2]),color='red')
            else:
                net.add_edge(idx2,idx1,width=15*np.abs(Df[idx1,idx2]),color='blue')

# %%
net.prep_notebook()
net.show("test.html")
# Out:
#         <iframe
#             width="800px"
#             height="600px"
#             src="test.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
net.show_buttons()

# %% [markdown]
# The graph seems to be relevant, so it is average over the whole time series to get meaningful connection

# %%
dfs = dfi

# %%
#build the time dependant correlation array:
window = 90#len(dfs)-2
cor_a = np.zeros((len(dfs.keys()),len(dfs.keys()),len(dfs)-window-1))

for idx1,key1 in enumerate(dfs.keys()):
    print(f"{idx1+1}/{len(dfs.keys())}",end='\r')
    for idx2,key2 in enumerate(dfs.keys()[idx1:]):
        idx2+=idx1
        cor_a[idx1,idx2,:]=np.squeeze(windowed_cor(dfs,key1,key2,window,1))
# Out:
# 95/96

# %%
#fill the missing values
cor_af = cor_a + np.transpose(cor_a, axes=[1,0,2])
for i in range(cor_af.shape[0]):
    cor_af[i,i,:]=cor_af[i,i,:]/2

# %%
par_cor = np.zeros((cor_af.shape[0],cor_af.shape[0],cor_af.shape[0],cor_af.shape[2]))
for start_date in range(cor_af.shape[2]):
    cor = cor_af[:,:,start_date]
    par_cor[:,:,:,start_date] = part_cor(cor)

# %%
par_cor.shape
# Out:
# (96, 96, 96, 899)

# %%
plt.imshow(np.mean(cor_af,axis=2),cmap='jet')
plt.colorbar()

# %%
d = np.repeat(np.expand_dims(cor_af,1),cor_af.shape[0],axis=1)-par_cor

# %%
d.shape
# Out:
# (96, 96, 96, 899)

# %%
size = d.shape[0]
D = np.sum(d,axis=1)
for j in range(size):
    D[:,j] -= d[:,j,j] 
D/=(d.shape[0]-1)

# %%
D.shape
# Out:
# (96, 96, 899)

# %%
plt.imshow(np.mean(D,axis=2),cmap='jet')
plt.colorbar()

# %%
Dm = np.mean(D,axis=-1)

# %%
th = 0.45
Df = np.copy(Dm)
Df[np.abs(Dm)<th]=0

# %%
net = Network(height='600px', width='800px', bgcolor='#FFFFFF', font_color='black',
              directed=True,layout=False)
net.barnes_hut()
for idx,key in enumerate(dfs.keys()):
    if key in taxa_keys:
        color = 'lime'
    elif key in cluster_keys: 
        color = 'green'
    elif key in water_keys:
        color = 'blue'
    elif key in meteo_keys:
        color = 'cyan'
    elif key in nut_keys:
        color = 'red'
    elif key in phys_keys:
        color = 'yellow'
    else:
        color = 'purple'
    net.add_node(idx, label=key, shape='dot',color=color,size=75)
    net.nodes[-1]['font']['size']=75
for idx1 in range(D.shape[0]):
    for idx2 in range(D.shape[0]):
        if idx1 != idx2 and Df[idx1,idx2] != 0:
            if Df[idx1,idx2]<0:
                net.add_edge(idx2,idx1,width=15*np.abs(Df[idx1,idx2]),color='red')
            else:
                net.add_edge(idx2,idx1,width=15*np.abs(Df[idx1,idx2]),color='blue')

# %%
net.prep_notebook()
net.show("threshold_045.html")
# Out:
#         <iframe
#             width="800px"
#             height="600px"
#             src="threshold_045.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
net.show_buttons()

# %%
size = Dm.shape[0]
edges=[]
for idx1 in range(size):
    for idx2 in range(size):
        if idx1 != idx2:
            edge = {'source': dfs.keys()[idx2], 'sink':dfs.keys()[idx1], 'weight':Dm[idx1,idx2]}
            edges.append(edge)

# %%
sorted_edges = sorted(edges,key= lambda x: np.abs(x['weight']),reverse=True)

# %%
sorted_edges
# Out:
# [{'source': 'mean_o2', 'sink': 'mean_o2ppm', 'weight': 1.06764074613528},
#  {'source': 'mean_cloud_cover',
#   'sink': 'sunshine_duration',
#   'weight': -1.0509715473882566},
#  {'source': 'mean_global_radiation',
#   'sink': 'sunshine_duration',
#   'weight': 1.0161190655355816},
#  {'source': 'mean_cloud_cover',
#   'sink': 'mean_global_radiation',
#   'weight': -0.980947401344443},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'mean_global_radiation',
#   'weight': -0.980752753580405},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'rel_air_humidity_min',
#   'weight': 0.9765310377333141},
#  {'source': 'sunshine_duration',
#   'sink': 'mean_cloud_cover',
#   'weight': -0.9562538090693795},
#  {'source': 'atmospheric_pressure_mean',
#   'sink': 'atmospheric_pressure_max',
#   'weight': 0.9096762634181069},
#  {'source': 'cv_par_depth', 'sink': 'mean_par', 'weight': 0.8968047202784009},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'mean_global_radiation',
#   'weight': -0.8922893496145807},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'sunshine_duration',
#   'weight': -0.880521820896866},
#  {'source': 'temp_mean', 'sink': 'temp_min', 'weight': 0.8715311504231082},
#  {'source': 'mean_global_radiation',
#   'sink': 'rel_air_humidity_min',
#   'weight': -0.8628999085917983},
#  {'source': 'windspeed_max',
#   'sink': 'windspeed_mean',
#   'weight': 0.8531555403918247},
#  {'source': 'rel_air_humidity_max',
#   'sink': 'rel_air_humidity_mean',
#   'weight': 0.8528592125861748},
#  {'source': 'mean_global_radiation',
#   'sink': 'mean_cloud_cover',
#   'weight': -0.8431549135957841},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'rel_air_humidity_mean',
#   'weight': 0.8408767735775247},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'mean_epi_temp',
#   'weight': -0.8347484498894315},
#  {'source': 'cv_o2_day', 'sink': 'cv_o2ppm_day', 'weight': 0.8252352204560512},
#  {'source': 'atmospheric_pressure_mean',
#   'sink': 'atmospheric_pressure_min',
#   'weight': 0.8245466329715753},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'temp_max',
#   'weight': -0.8234505847185911},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'sunshine_duration',
#   'weight': -0.8150735510279482},
#  {'source': 'temp_mean', 'sink': 'temp_max', 'weight': 0.8147332609493688},
#  {'source': 'windspeed_mean',
#   'sink': 'windspeed_max',
#   'weight': 0.8023792404708855},
#  {'source': 'mean_global_radiation',
#   'sink': 'rel_air_humidity_mean',
#   'weight': -0.7895365808145134},
#  {'source': 'atmospheric_pressure_min',
#   'sink': 'atmospheric_pressure_max',
#   'weight': 0.7881055347091505},
#  {'source': 'atmospheric_pressure_min',
#   'sink': 'atmospheric_pressure_mean',
#   'weight': 0.7811411806651778},
#  {'source': 'sunshine_duration',
#   'sink': 'rel_air_humidity_min',
#   'weight': -0.7661772862163108},
#  {'source': 'cluster_1', 'sink': 'cluster_2', 'weight': 0.7585351508946702},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'mean_temp',
#   'weight': -0.7559100799605358},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'mean_cloud_cover',
#   'weight': 0.7552535906788045},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'mean_condF',
#   'weight': -0.7436005743732133},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'temp_max',
#   'weight': -0.7391565188067567},
#  {'source': 'cv_o2_depth',
#   'sink': 'cv_o2ppm_depth',
#   'weight': 0.7389181522623484},
#  {'source': 'mean_schmidt', 'sink': 'mean_temp', 'weight': 0.7386740184210503},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'cv_temp_depth',
#   'weight': -0.7366264157018769},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'rel_air_humidity_max',
#   'weight': 0.7304947779146415},
#  {'source': 'atmospheric_pressure_max',
#   'sink': 'atmospheric_pressure_min',
#   'weight': 0.7304424678196113},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'mean_schmidt',
#   'weight': -0.7277580748597186},
#  {'source': 'atmospheric_pressure_max',
#   'sink': 'atmospheric_pressure_mean',
#   'weight': 0.7237962517481227},
#  {'source': 'mean_cloud_cover',
#   'sink': 'rel_air_humidity_min',
#   'weight': 0.7232640122087008},
#  {'source': 'sunshine_duration',
#   'sink': 'rel_air_humidity_mean',
#   'weight': -0.7218956551812206},
#  {'source': 'mean_schmidt',
#   'sink': 'mean_epi_temp',
#   'weight': 0.7186980657930698},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'mean_schmidt',
#   'weight': -0.713269425145125},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'mean_cloud_cover',
#   'weight': 0.7106771190788347},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'mean_epi_temp',
#   'weight': -0.6974338100950493},
#  {'source': 'temp_max',
#   'sink': 'rel_air_humidity_min',
#   'weight': -0.6966960316025405},
#  {'source': 'temp_max', 'sink': 'temp_mean', 'weight': 0.693419456325218},
#  {'source': 'mean_par', 'sink': 'cv_par_depth', 'weight': 0.6880126350880081},
#  {'source': 'mean_cloud_cover',
#   'sink': 'temp_max',
#   'weight': -0.6875883136706727},
#  {'source': 'mean_schmidt',
#   'sink': 'mean_condF',
#   'weight': 0.6873159947401444},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'cv_temp_depth',
#   'weight': -0.6739091175562113},
#  {'source': 'mean_global_radiation',
#   'sink': 'cv_par_depth',
#   'weight': 0.6688558817340362},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'mean_temp',
#   'weight': -0.6632884516942104},
#  {'source': 'mean_epi_temp',
#   'sink': 'mean_thermocline_depth',
#   'weight': -0.6604982252654155},
#  {'source': 'mean_global_radiation',
#   'sink': 'mean_par',
#   'weight': 0.6587839331518072},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'temp_mean',
#   'weight': -0.6544415209829371},
#  {'source': 'temp_max', 'sink': 'temp_min', 'weight': 0.6542981177782237},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'cv_ph_depth',
#   'weight': -0.652967526069774},
#  {'source': 'temp_max',
#   'sink': 'mean_global_radiation',
#   'weight': 0.6468949619805887},
#  {'source': 'mean_cloud_cover',
#   'sink': 'rel_air_humidity_mean',
#   'weight': 0.6462406359571817},
#  {'source': 'cv_o2ppm_day', 'sink': 'cv_o2_day', 'weight': 0.6449230920016249},
#  {'source': 'cluster_6', 'sink': 'asterionella', 'weight': 0.6414233780640953},
#  {'source': 'cv_condF_day',
#   'sink': 'cv_temp_day',
#   'weight': 0.640425988138909},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'temp_mean',
#   'weight': -0.6388249538990052},
#  {'source': 'cluster_4', 'sink': 'diatom', 'weight': 0.638305958628268},
#  {'source': 'sunshine_duration',
#   'sink': 'mean_global_radiation',
#   'weight': 0.6376530894551152},
#  {'source': 'TP', 'sink': 'mean_condF', 'weight': -0.6350561610110924},
#  {'source': 'TP', 'sink': 'mean_epi_temp', 'weight': -0.6336957925845217},
#  {'source': 'cv_o2ppm_depth',
#   'sink': 'cv_o2_depth',
#   'weight': 0.6289905969603372},
#  {'source': 'Ammonium', 'sink': 'mean_epi_temp', 'weight': -0.626438449019264},
#  {'source': 'rel_air_humidity_max',
#   'sink': 'rel_air_humidity_min',
#   'weight': 0.6250558504767479},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'cv_par_depth',
#   'weight': -0.6250214386722358},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'cv_epi_temp',
#   'weight': -0.6249514341514603},
#  {'source': 'cv_epi_temp', 'sink': 'cv_thermo', 'weight': 0.6214527589847055},
#  {'source': 'temp_min', 'sink': 'temp_mean', 'weight': 0.6214225192241281},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'cv_o2_depth',
#   'weight': -0.6161984807734318},
#  {'source': 'temp_max',
#   'sink': 'sunshine_duration',
#   'weight': 0.6161332030536932},
#  {'source': 'cv_par_depth',
#   'sink': 'ml_irradiance',
#   'weight': 0.6126748474100623},
#  {'source': 'TP', 'sink': 'mean_temp', 'weight': -0.6087414193577728},
#  {'source': 'temp_max',
#   'sink': 'rel_air_humidity_mean',
#   'weight': -0.6075673989996142},
#  {'source': 'temp_min', 'sink': 'temp_max', 'weight': 0.598077644712186},
#  {'source': 'mean_cloud_cover',
#   'sink': 'cv_par_depth',
#   'weight': -0.597370914184895},
#  {'source': 'cluster_3', 'sink': 'cluster_2', 'weight': 0.596819080304044},
#  {'source': 'cluster_5', 'sink': 'cluster_6', 'weight': 0.5932654574568951},
#  {'source': 'Ammonium', 'sink': 'mean_condF', 'weight': -0.5930986721899961},
#  {'source': 'Ammonium', 'sink': 'mean_schmidt', 'weight': -0.5921078795556288},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'temp_mean',
#   'weight': -0.59186764081484},
#  {'source': 'mean_par', 'sink': 'ml_irradiance', 'weight': 0.5904993390943942},
#  {'source': 'cluster_7', 'sink': 'cluster_6', 'weight': 0.5888632429420585},
#  {'source': 'cv_temp_day',
#   'sink': 'cv_condF_day',
#   'weight': 0.5882215419263745},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'cv_par_depth',
#   'weight': -0.5881591888699589},
#  {'source': 'ciliate', 'sink': 'cluster_4', 'weight': 0.5869557300119658},
#  {'source': 'cv_temp_depth',
#   'sink': 'cv_condF_depth',
#   'weight': 0.5866345044224894},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'mean_par',
#   'weight': -0.5854326114730736},
#  {'source': 'Ammonium', 'sink': 'cluster_1', 'weight': -0.5834598231167204},
#  {'source': 'cluster_1', 'sink': 'cluster_3', 'weight': 0.5821627340189947},
#  {'source': 'ciliate', 'sink': 'diatom', 'weight': 0.5819947803595675},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'cluster_1',
#   'weight': -0.5806550054062923},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'temp_mean',
#   'weight': -0.5794584193289172},
#  {'source': 'mean_epi_temp',
#   'sink': 'mean_condF',
#   'weight': 0.5784955573008461},
#  {'source': 'rotifers', 'sink': 'polyarthra', 'weight': 0.5782842278278383},
#  {'source': 'cluster_6', 'sink': 'cluster_5', 'weight': 0.578169544023912},
#  {'source': 'mean_temp',
#   'sink': 'mean_epi_temp',
#   'weight': 0.5756011475474063},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'cv_o2ppm_depth',
#   'weight': -0.5749596206534173},
#  {'source': 'ciliate', 'sink': 'cluster_5', 'weight': 0.5729896555889025},
#  {'source': 'mean_temp', 'sink': 'mean_condF', 'weight': 0.5698604731201646},
#  {'source': 'Ammonium', 'sink': 'mean_temp', 'weight': -0.5697548415824807},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'cv_thermo',
#   'weight': -0.5693527477232673},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'temp_max',
#   'weight': -0.5693234567732506},
#  {'source': 'cluster_4', 'sink': 'ciliate', 'weight': 0.5687676015735249},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'cluster_3',
#   'weight': -0.5681379060186339},
#  {'source': 'rel_air_humidity_max',
#   'sink': 'mean_global_radiation',
#   'weight': -0.5675377538187311},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'temp_max',
#   'weight': -0.5631291652284997},
#  {'source': 'TP', 'sink': 'mean_schmidt', 'weight': -0.5607597521377012},
#  {'source': 'mean_epi_temp',
#   'sink': 'mean_temp',
#   'weight': 0.5601333081332746},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'cv_condF_depth',
#   'weight': -0.5596205765217112},
#  {'source': 'precipitation_tot',
#   'sink': 'mean_global_radiation',
#   'weight': -0.5553169922251587},
#  {'source': 'cluster_2', 'sink': 'cluster_3', 'weight': 0.5543077743645113},
#  {'source': 'oP', 'sink': 'mean_condF', 'weight': -0.5539535704174522},
#  {'source': 'TP', 'sink': 'oP', 'weight': 0.5508911577642306},
#  {'source': 'cluster_6', 'sink': 'cluster_7', 'weight': 0.5501713549680857},
#  {'source': 'cv_par_depth',
#   'sink': 'sunshine_duration',
#   'weight': 0.5497681270351964},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'mean_schmidt',
#   'weight': -0.5490013526584842},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'mean_par',
#   'weight': -0.5489703560093415},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'temp_min',
#   'weight': -0.5481023890687796},
#  {'source': 'cluster_2', 'sink': 'cluster_1', 'weight': 0.5474943487581162},
#  {'source': 'mean_cloud_cover',
#   'sink': 'mean_par',
#   'weight': -0.5467562836757623},
#  {'source': 'sunshine_duration',
#   'sink': 'cv_par_depth',
#   'weight': 0.5465004610527916},
#  {'source': 'cluster_5', 'sink': 'ciliate', 'weight': 0.5456487398852998},
#  {'source': 'Ammonium', 'sink': 'mean_o2', 'weight': -0.5453161415644456},
#  {'source': 'mean_global_radiation',
#   'sink': 'ml_irradiance',
#   'weight': 0.5451606947389531},
#  {'source': 'cluster_5', 'sink': 'cluster_8', 'weight': 0.5449980699969857},
#  {'source': 'temp_max',
#   'sink': 'mean_cloud_cover',
#   'weight': -0.5445253759692333},
#  {'source': 'cluster_6', 'sink': 'cluster_8', 'weight': 0.5442919627439401},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'temp_min',
#   'weight': -0.5418922197892956},
#  {'source': 'cluster_5', 'sink': 'diatom', 'weight': 0.5401529061563223},
#  {'source': 'rel_air_humidity_max',
#   'sink': 'sunshine_duration',
#   'weight': -0.5396843293161657},
#  {'source': 'oP', 'sink': 'mean_epi_temp', 'weight': -0.5395386013434181},
#  {'source': 'cluster_5', 'sink': 'ceratium', 'weight': 0.5375373598523722},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'mean_o2',
#   'weight': -0.5370940700114053},
#  {'source': 'mean_cloud_cover',
#   'sink': 'temp_mean',
#   'weight': -0.5368797230838163},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'cv_ph_depth',
#   'weight': -0.5365141005034896},
#  {'source': 'ml_irradiance', 'sink': 'mean_par', 'weight': 0.5302325406451737},
#  {'source': 'cluster_4', 'sink': 'cluster_5', 'weight': 0.5274731403841317},
#  {'source': 'mean_schmidt', 'sink': 'temp_min', 'weight': 0.5274206357360982},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'rel_air_humidity_max',
#   'weight': 0.5273067289791967},
#  {'source': 'cluster_3', 'sink': 'cluster_1', 'weight': 0.525243165891942},
#  {'source': 'mean_chla', 'sink': 'diatom', 'weight': 0.5248662011093841},
#  {'source': 'cv_temp_depth',
#   'sink': 'mean_thermocline_depth',
#   'weight': -0.523993324826785},
#  {'source': 'keratella_cochlearis',
#   'sink': 'keratella_quadrata',
#   'weight': 0.5236221743299261},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'cv_condF_depth',
#   'weight': -0.5231378202000976},
#  {'source': 'sunshine_duration',
#   'sink': 'mean_par',
#   'weight': 0.5217208235989695},
#  {'source': 'cluster_5', 'sink': 'cluster_4', 'weight': 0.5211098591141683},
#  {'source': 'ml_irradiance',
#   'sink': 'cv_par_depth',
#   'weight': 0.5208303247723645},
#  {'source': 'precipitation_tot',
#   'sink': 'sunshine_duration',
#   'weight': -0.520643295034374},
#  {'source': 'cv_par_depth',
#   'sink': 'mean_global_radiation',
#   'weight': 0.5204224694091606},
#  {'source': 'Ammonium', 'sink': 'cluster_3', 'weight': -0.517924992714516},
#  {'source': 'temp_max', 'sink': 'cv_par_depth', 'weight': 0.5164944454789039},
#  {'source': 'ciliate', 'sink': 'cluster_8', 'weight': 0.5161154587723041},
#  {'source': 'cluster_4', 'sink': 'mean_chla', 'weight': 0.5149037481909141},
#  {'source': 'oP', 'sink': 'Ammonium', 'weight': 0.5127771988004886},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'cluster_2',
#   'weight': -0.5123056095993845},
#  {'source': 'rel_air_humidity_max',
#   'sink': 'mean_cloud_cover',
#   'weight': 0.5120159727326635},
#  {'source': 'TP', 'sink': 'Ammonium', 'weight': 0.5113788966461063},
#  {'source': 'mean_condF', 'sink': 'TP', 'weight': -0.5091887821323146},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'temp_min',
#   'weight': -0.5058323011347741},
#  {'source': 'cv_par_depth',
#   'sink': 'rel_air_humidity_min',
#   'weight': -0.5040533066272831},
#  {'source': 'oP', 'sink': 'mean_temp', 'weight': -0.5031793385352835},
#  {'source': 'mean_ph', 'sink': 'cv_ph_depth', 'weight': -0.5019394721717455},
#  {'source': 'mean_global_radiation',
#   'sink': 'precipitation_tot',
#   'weight': -0.5005962877785596},
#  {'source': 'mean_epi_temp', 'sink': 'TP', 'weight': -0.5004507453441573},
#  {'source': 'mean_epi_temp',
#   'sink': 'temp_min',
#   'weight': 0.49979848370914537},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'temp_mean',
#   'weight': -0.49902728748097663},
#  {'source': 'mean_chla', 'sink': 'cluster_4', 'weight': 0.4986020729523191},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'cluster_2',
#   'weight': -0.49732125627092094},
#  {'source': 'cluster_1', 'sink': 'cluster_4', 'weight': 0.4970658824910439},
#  {'source': 'mean_chla', 'sink': 'ciliate', 'weight': 0.49610159326298475},
#  {'source': 'Ammonium', 'sink': 'temp_mean', 'weight': -0.49605910568429873},
#  {'source': 'Ammonium', 'sink': 'cluster_2', 'weight': -0.496058702099339},
#  {'source': 'mean_condF',
#   'sink': 'mean_thermocline_depth',
#   'weight': -0.49583764876061825},
#  {'source': 'month',
#   'sink': 'mean_mixed_layer_depth',
#   'weight': 0.49270141956746477},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'cv_epi_temp',
#   'weight': -0.49214488770594644},
#  {'source': 'precipitation_tot',
#   'sink': 'mean_cloud_cover',
#   'weight': 0.49202080146161287},
#  {'source': 'mean_schmidt',
#   'sink': 'cv_temp_depth',
#   'weight': 0.4903454273388322},
#  {'source': 'mean_par',
#   'sink': 'sunshine_duration',
#   'weight': 0.48863956530530445},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'mean_condF',
#   'weight': -0.4878146517520003},
#  {'source': 'cluster_4', 'sink': 'cluster_3', 'weight': 0.4878020838473322},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'cluster_4',
#   'weight': -0.4875413322054197},
#  {'source': 'precipitation_tot',
#   'sink': 'rel_air_humidity_min',
#   'weight': 0.4872620453204701},
#  {'source': 'mean_par',
#   'sink': 'mean_global_radiation',
#   'weight': 0.4869548895335384},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'cluster_1',
#   'weight': -0.4863075430396235},
#  {'source': 'precipitation_tot',
#   'sink': 'rel_air_humidity_mean',
#   'weight': 0.4859139746012039},
#  {'source': 'cluster_3', 'sink': 'cluster_4', 'weight': 0.4852360024561464},
#  {'source': 'mean_temp',
#   'sink': 'mean_oxycline_depth',
#   'weight': -0.4849280081781186},
#  {'source': 'cluster_4', 'sink': 'cluster_1', 'weight': 0.4843982627162823},
#  {'source': 'Ammonium', 'sink': 'temp_min', 'weight': -0.48298948974196315},
#  {'source': 'temp_max', 'sink': 'mean_par', 'weight': 0.482569708595801},
#  {'source': 'temp_mean',
#   'sink': 'rel_air_humidity_mean',
#   'weight': -0.4812823088582922},
#  {'source': 'cv_par_depth',
#   'sink': 'rel_air_humidity_mean',
#   'weight': -0.48018245822514743},
#  {'source': 'keratella_cochlearis',
#   'sink': 'brachionus',
#   'weight': 0.479972280775887},
#  {'source': 'TP', 'sink': 'mean_o2', 'weight': -0.4794391336756845},
#  {'source': 'mean_global_radiation',
#   'sink': 'rel_air_humidity_max',
#   'weight': -0.47940492530027135},
#  {'source': 'temp_mean',
#   'sink': 'rel_air_humidity_min',
#   'weight': -0.4784731481457455},
#  {'source': 'cv_temp_depth',
#   'sink': 'mean_mixed_layer_depth',
#   'weight': -0.47836464218843366},
#  {'source': 'Ammonium',
#   'sink': 'mean_thermocline_depth',
#   'weight': 0.478145752674549},
#  {'source': 'ciliate', 'sink': 'mean_chla', 'weight': 0.47773830270993856},
#  {'source': 'sunshine_duration',
#   'sink': 'ml_irradiance',
#   'weight': 0.47724973225426065},
#  {'source': 'cv_par_depth',
#   'sink': 'mean_cloud_cover',
#   'weight': -0.47641016614614756},
#  {'source': 'mean_global_radiation',
#   'sink': 'temp_max',
#   'weight': 0.4763816111435699},
#  {'source': 'ciliate', 'sink': 'cluster_6', 'weight': 0.47474710883833815},
#  {'source': 'Ammonium', 'sink': 'temp_max', 'weight': -0.4744490975068843},
#  {'source': 'cv_condF_depth',
#   'sink': 'cv_temp_depth',
#   'weight': 0.4730847930117915},
#  {'source': 'sunshine_duration',
#   'sink': 'rel_air_humidity_max',
#   'weight': -0.4724968585231068},
#  {'source': 'leptodora', 'sink': 'chaoborus', 'weight': 0.47214516398274287},
#  {'source': 'sunshine_duration',
#   'sink': 'precipitation_tot',
#   'weight': -0.4720956934239025},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'mean_epi_temp',
#   'weight': -0.4713108427526085},
#  {'source': 'diatom', 'sink': 'cluster_4', 'weight': 0.47117285530120107},
#  {'source': 'mean_schmidt',
#   'sink': 'temp_mean',
#   'weight': 0.47022718827677307},
#  {'source': 'mean_epi_temp',
#   'sink': 'mean_schmidt',
#   'weight': 0.470020841713913},
#  {'source': 'diatom', 'sink': 'mean_chla', 'weight': 0.46800429442726227},
#  {'source': 'cluster_6', 'sink': 'ciliate', 'weight': 0.467100008837248},
#  {'source': 'cv_thermo',
#   'sink': 'mean_thermocline_depth',
#   'weight': -0.4655110245379829},
#  {'source': 'mean_temp', 'sink': 'TP', 'weight': -0.4654791122737069},
#  {'source': 'rel_air_humidity_max',
#   'sink': 'temp_max',
#   'weight': -0.46538369078023867},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'cluster_2',
#   'weight': -0.4644461199814191},
#  {'source': 'keratella_cochlearis',
#   'sink': 'dinobryon',
#   'weight': 0.46410822370847066},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'ml_irradiance',
#   'weight': -0.4624689650252385},
#  {'source': 'cluster_8', 'sink': 'cluster_6', 'weight': 0.4613525269645975},
#  {'source': 'keratella_quadrata',
#   'sink': 'keratella_cochlearis',
#   'weight': 0.46091851420707874},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'temp_max',
#   'weight': -0.4607395972391414},
#  {'source': 'oP', 'sink': 'mean_schmidt', 'weight': -0.4595889617453175},
#  {'source': 'mean_par',
#   'sink': 'rel_air_humidity_min',
#   'weight': -0.459291645593521},
#  {'source': 'temp_min',
#   'sink': 'mean_epi_temp',
#   'weight': 0.45903923142035513},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'cluster_1',
#   'weight': -0.4590237750811417},
#  {'source': 'cv_epi_temp',
#   'sink': 'cv_temp_day',
#   'weight': 0.4589505405909417},
#  {'source': 'temp_mean',
#   'sink': 'mean_global_radiation',
#   'weight': 0.4587388336286217},
#  {'source': 'cluster_5', 'sink': 'asterionella', 'weight': 0.4585946907205052},
#  {'source': 'cv_condF_depth',
#   'sink': 'cv_condF_day',
#   'weight': 0.4585423339355382},
#  {'source': 'diatom', 'sink': 'ciliate', 'weight': 0.45761350931425615},
#  {'source': 'Ammonium', 'sink': 'cv_epi_temp', 'weight': -0.4563290842077812},
#  {'source': 'mean_ph', 'sink': 'mean_temp', 'weight': -0.4552300200667638},
#  {'source': 'Ammonium', 'sink': 'mean_chla', 'weight': -0.4541716817279635},
#  {'source': 'mean_temp', 'sink': 'mean_schmidt', 'weight': 0.4540928292826179},
#  {'source': 'mean_cloud_cover',
#   'sink': 'ml_irradiance',
#   'weight': -0.4540054115539134},
#  {'source': 'cluster_5', 'sink': 'mean_chla', 'weight': 0.4535841540558193},
#  {'source': 'mean_condF',
#   'sink': 'mean_epi_temp',
#   'weight': 0.4521553058728344},
#  {'source': 'mean_schmidt',
#   'sink': 'mean_thermocline_depth',
#   'weight': -0.4520517225883367},
#  {'source': 'ciliate', 'sink': 'cluster_7', 'weight': 0.4512612519876181},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'mean_o2ppm',
#   'weight': -0.4509941421111709},
#  {'source': 'temp_mean',
#   'sink': 'cv_temp_depth',
#   'weight': 0.4502496970135181},
#  {'source': 'ciliate', 'sink': 'cluster_3', 'weight': 0.4501773362194748},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'diaphanosoma',
#   'weight': -0.449882519439586},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'cyclops',
#   'weight': -0.4493129521196359},
#  {'source': 'diatom', 'sink': 'cluster_5', 'weight': 0.4482510217540958},
#  {'source': 'mean_condF', 'sink': 'Nitrat', 'weight': 0.448185745735942},
#  {'source': 'cluster_1', 'sink': 'ciliate', 'weight': 0.4478201261316886},
#  {'source': 'cluster_3', 'sink': 'ciliate', 'weight': 0.44760727056848765},
#  {'source': 'Ammonium', 'sink': 'trichocerca', 'weight': -0.44726167666428923},
#  {'source': 'temp_max', 'sink': 'ml_irradiance', 'weight': 0.4468582342397943},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'Ammonium',
#   'weight': 0.44678745138956644},
#  {'source': 'temp_min', 'sink': 'mean_schmidt', 'weight': 0.44664600158368195},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'cluster_2',
#   'weight': -0.44530534650806275},
#  {'source': 'mean_o2ppm', 'sink': 'mean_o2', 'weight': 0.4452868754540056},
#  {'source': 'ceratium', 'sink': 'paradileptus', 'weight': 0.4449824974627255},
#  {'source': 'TP',
#   'sink': 'mean_thermocline_depth',
#   'weight': 0.44465815955024235},
#  {'source': 'cv_ph_depth',
#   'sink': 'cv_o2_depth',
#   'weight': 0.44387442914467257},
#  {'source': 'mean_epi_temp',
#   'sink': 'temp_mean',
#   'weight': 0.4427947854336973},
#  {'source': 'mean_temp', 'sink': 'temp_min', 'weight': 0.4411236443772032},
#  {'source': 'cluster_6', 'sink': 'ceratium', 'weight': 0.4401121930215645},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'cv_oxycline_depth',
#   'weight': -0.4401104461888193},
#  {'source': 'keratella_cochlearis',
#   'sink': 'paradileptus',
#   'weight': 0.4400458786069326},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'cluster_3',
#   'weight': -0.4400090480976361},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'cluster_1',
#   'weight': -0.4398111319975688},
#  {'source': 'temp_mean',
#   'sink': 'mean_epi_temp',
#   'weight': 0.43711644518269355},
#  {'source': 'ceratium', 'sink': 'cluster_5', 'weight': 0.43696533457331727},
#  {'source': 'mean_par',
#   'sink': 'rel_air_humidity_mean',
#   'weight': -0.43685307093723197},
#  {'source': 'cluster_3', 'sink': 'mean_chla', 'weight': 0.436794076940767},
#  {'source': 'mean_chla', 'sink': 'cluster_5', 'weight': 0.43644873773054993},
#  {'source': 'cv_ph_depth',
#   'sink': 'cv_o2ppm_depth',
#   'weight': 0.43625108225000847},
#  {'source': 'rel_air_humidity_max',
#   'sink': 'temp_mean',
#   'weight': -0.4345180996951121},
#  {'source': 'cluster_7', 'sink': 'cluster_8', 'weight': 0.4344150173989904},
#  {'source': 'cluster_5', 'sink': 'cluster_7', 'weight': 0.433552522259147},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'ml_irradiance',
#   'weight': -0.43350737088903335},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'cluster_3',
#   'weight': -0.43345851225667764},
#  {'source': 'dinobryon',
#   'sink': 'keratella_cochlearis',
#   'weight': 0.431901878314511},
#  {'source': 'mean_condF', 'sink': 'oP', 'weight': -0.43143798658618127},
#  {'source': 'cluster_6', 'sink': 'diatom', 'weight': 0.4304544869563086},
#  {'source': 'chaoborus', 'sink': 'leptodora', 'weight': 0.43018287605295363},
#  {'source': 'mean_cloud_cover',
#   'sink': 'rel_air_humidity_max',
#   'weight': 0.4298369584160927},
#  {'source': 'temp_mean', 'sink': 'mean_schmidt', 'weight': 0.429268243348053},
#  {'source': 'brachionus',
#   'sink': 'keratella_cochlearis',
#   'weight': 0.4290237425490228},
#  {'source': 'cluster_8', 'sink': 'cluster_5', 'weight': 0.4281945631440646},
#  {'source': 'mean_epi_temp',
#   'sink': 'cv_temp_depth',
#   'weight': 0.42772140001331593},
#  {'source': 'cv_chla_depth',
#   'sink': 'cv_o2ppm_depth',
#   'weight': 0.42720325566227196},
#  {'source': 'cv_temp_depth',
#   'sink': 'cv_temp_day',
#   'weight': 0.42714309320672783},
#  {'source': 'windspeed_max',
#   'sink': 'atmospheric_pressure_min',
#   'weight': -0.42672429280509544},
#  {'source': 'cluster_1', 'sink': 'mean_chla', 'weight': 0.4262749804158249},
#  {'source': 'cluster_7', 'sink': 'cluster_5', 'weight': 0.42537565453426823},
#  {'source': 'Ammonium', 'sink': 'cluster_4', 'weight': -0.42515782509161154},
#  {'source': 'oP',
#   'sink': 'mean_thermocline_depth',
#   'weight': 0.4248799443506587},
#  {'source': 'temp_max', 'sink': 'cv_temp_depth', 'weight': 0.4247154700950438},
#  {'source': 'cv_epi_temp',
#   'sink': 'cv_temp_depth',
#   'weight': 0.42470489666043576},
#  {'source': 'mean_schmidt',
#   'sink': 'mean_oxycline_depth',
#   'weight': -0.42388927774419327},
#  {'source': 'mean_condF',
#   'sink': 'cv_temp_depth',
#   'weight': 0.4232739422462996},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'mean_condF',
#   'weight': -0.4231424024652407},
#  {'source': 'cluster_4', 'sink': 'cluster_2', 'weight': 0.4228768123166739},
#  {'source': 'cv_temp_depth',
#   'sink': 'ml_irradiance',
#   'weight': 0.42255028371888664},
#  {'source': 'cv_thermo', 'sink': 'cv_epi_temp', 'weight': 0.4216680010860838},
#  {'source': 'temp_min', 'sink': 'mean_temp', 'weight': 0.421122242102771},
#  {'source': 'Ammonium', 'sink': 'mean_o2ppm', 'weight': -0.42019145775863803},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'cv_condF_day',
#   'weight': -0.4194822704283043},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'mean_temp',
#   'weight': -0.4192530816988229},
#  {'source': 'mean_epi_temp',
#   'sink': 'Ammonium',
#   'weight': -0.41881726022937804},
#  {'source': 'cluster_7', 'sink': 'ciliate', 'weight': 0.41869058861110064},
#  {'source': 'mean_chla', 'sink': 'cluster_3', 'weight': 0.41858784089688156},
#  {'source': 'diatom', 'sink': 'cluster_8', 'weight': 0.41769641872346036},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'cluster_3',
#   'weight': -0.4174710153901346},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'cluster_2',
#   'weight': -0.4170993172526919},
#  {'source': 'mean_par',
#   'sink': 'mean_cloud_cover',
#   'weight': -0.4165073059888118},
#  {'source': 'paradileptus', 'sink': 'ceratium', 'weight': 0.4160070085692772},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'cluster_1',
#   'weight': -0.4158075469720359},
#  {'source': 'cv_o2ppm_depth',
#   'sink': 'cv_o2ppm_day',
#   'weight': 0.41467328680528603},
#  {'source': 'temp_mean', 'sink': 'cv_par_depth', 'weight': 0.4146355137996411},
#  {'source': 'cluster_1', 'sink': 'cv_ph_depth', 'weight': 0.41373563521798623},
#  {'source': 'mean_schmidt', 'sink': 'temp_max', 'weight': 0.4127868421535234},
#  {'source': 'dinobryon', 'sink': 'uroglena', 'weight': 0.4113816519492331},
#  {'source': 'mean_ph',
#   'sink': 'cv_o2ppm_depth',
#   'weight': -0.4108460585458324},
#  {'source': 'mean_chla', 'sink': 'cluster_1', 'weight': 0.40922757504814994},
#  {'source': 'cluster_8',
#   'sink': 'asterionella',
#   'weight': 0.40872389970513423},
#  {'source': 'mean_cloud_cover',
#   'sink': 'cluster_2',
#   'weight': -0.40740508817153626},
#  {'source': 'paradileptus',
#   'sink': 'keratella_cochlearis',
#   'weight': 0.40536283951018504},
#  {'source': 'temp_mean',
#   'sink': 'sunshine_duration',
#   'weight': 0.4051779696659995},
#  {'source': 'cv_epi_temp',
#   'sink': 'mean_thermocline_depth',
#   'weight': -0.40499950364291837},
#  {'source': 'mean_epi_temp', 'sink': 'oP', 'weight': -0.40447915141825064},
#  {'source': 'temp_min',
#   'sink': 'cv_temp_depth',
#   'weight': 0.40424622370833535},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'cv_par_depth',
#   'weight': -0.4040961994220388},
#  {'source': 'cv_o2ppm_depth',
#   'sink': 'cv_chla_depth',
#   'weight': 0.4040577134802906},
#  {'source': 'mean_cloud_cover',
#   'sink': 'atmospheric_pressure_min',
#   'weight': -0.40359663477930285},
#  {'source': 'mean_temp',
#   'sink': 'mean_thermocline_depth',
#   'weight': -0.4030972591761862},
#  {'source': 'uroglena', 'sink': 'dinobryon', 'weight': 0.40263001826461187},
#  {'source': 'Nitrat', 'sink': 'TN', 'weight': 0.4024047310771285},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'ml_irradiance',
#   'weight': -0.40199381791884836},
#  {'source': 'sunshine_duration',
#   'sink': 'temp_max',
#   'weight': 0.40116694843464606},
#  {'source': 'cv_o2ppm_depth',
#   'sink': 'cv_o2_day',
#   'weight': 0.4010681871029489},
#  {'source': 'cluster_6', 'sink': 'mean_chla', 'weight': 0.4007256484313928},
#  {'source': 'cluster_5',
#   'sink': 'keratella_cochlearis',
#   'weight': 0.40046338877215093},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'mean_global_radiation',
#   'weight': -0.40033693680443644},
#  {'source': 'cluster_4', 'sink': 'cluster_7', 'weight': 0.4000035243894172},
#  {'source': 'mean_epi_temp',
#   'sink': 'mean_oxycline_depth',
#   'weight': -0.3992049397339336},
#  {'source': 'cluster_7', 'sink': 'asterionella', 'weight': 0.3991656745932042},
#  {'source': 'cluster_1', 'sink': 'trichocerca', 'weight': 0.39882761208149103},
#  {'source': 'ml_irradiance',
#   'sink': 'sunshine_duration',
#   'weight': 0.3986037722071558},
#  {'source': 'cv_condF_depth',
#   'sink': 'cv_o2ppm_depth',
#   'weight': 0.39859332672752174},
#  {'source': 'Ammonium',
#   'sink': 'cv_temp_depth',
#   'weight': -0.39763637505389093},
#  {'source': 'mean_chla', 'sink': 'cluster_6', 'weight': 0.3964593652501841},
#  {'source': 'keratella_cochlearis',
#   'sink': 'ceratium',
#   'weight': 0.39642391717008896},
#  {'source': 'temp_min', 'sink': 'mean_condF', 'weight': 0.39564765143286834},
#  {'source': 'mean_cloud_cover',
#   'sink': 'atmospheric_pressure_mean',
#   'weight': -0.395383490549103},
#  {'source': 'asterionella', 'sink': 'cluster_6', 'weight': 0.395205579483732},
#  {'source': 'mean_cloud_cover',
#   'sink': 'cluster_1',
#   'weight': -0.39505067505181335},
#  {'source': 'mean_schmidt',
#   'sink': 'cv_epi_temp',
#   'weight': 0.3948787231238986},
#  {'source': 'oP', 'sink': 'TP', 'weight': 0.39427548690103337},
#  {'source': 'cluster_4', 'sink': 'cluster_6', 'weight': 0.39360632744216406},
#  {'source': 'mean_schmidt',
#   'sink': 'cv_ph_depth',
#   'weight': 0.3934708398389011},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'cv_temp_depth',
#   'weight': -0.3934129618970889},
#  {'source': 'cv_temp_depth',
#   'sink': 'cv_epi_temp',
#   'weight': 0.3930692057524878},
#  {'source': 'cluster_5', 'sink': 'fragilaria', 'weight': 0.3924883781394923},
#  {'source': 'cv_o2_depth',
#   'sink': 'cv_o2ppm_day',
#   'weight': 0.39239810514496015},
#  {'source': 'mean_ph', 'sink': 'mean_schmidt', 'weight': -0.3920055298146244},
#  {'source': 'atmospheric_pressure_min',
#   'sink': 'windspeed_max',
#   'weight': -0.3919881641625828},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'ciliate',
#   'weight': -0.39194932686601114},
#  {'source': 'cv_chla_depth',
#   'sink': 'cv_o2_depth',
#   'weight': 0.3901279661876727},
#  {'source': 'Ammonium', 'sink': 'cyclops', 'weight': -0.3899231992255171},
#  {'source': 'cyclops', 'sink': 'daphnia', 'weight': 0.38989180119066247},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'precipitation_tot',
#   'weight': 0.3895029515704428},
#  {'source': 'Ammonium', 'sink': 'oP', 'weight': 0.3886922065582984},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'cv_ph_depth',
#   'weight': -0.3885995993892555},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'cluster_7',
#   'weight': -0.38809621412083883},
#  {'source': 'mean_epi_temp',
#   'sink': 'temp_max',
#   'weight': 0.38806558348007814},
#  {'source': 'ciliate', 'sink': 'cluster_1', 'weight': 0.38798941476045656},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'trichocerca',
#   'weight': -0.38790864226083216},
#  {'source': 'Ammonium', 'sink': 'cluster_7', 'weight': -0.3878878961781492},
#  {'source': 'rel_air_humidity_max',
#   'sink': 'cv_par_depth',
#   'weight': -0.3878810213040309},
#  {'source': 'mean_ph', 'sink': 'cv_o2_depth', 'weight': -0.387738835918},
#  {'source': 'oP', 'sink': 'Nitrat', 'weight': -0.3875308036111391},
#  {'source': 'temp_mean', 'sink': 'mean_temp', 'weight': 0.38730779940804855},
#  {'source': 'TP', 'sink': 'temp_mean', 'weight': -0.38641765094887676},
#  {'source': 'temp_mean', 'sink': 'mean_condF', 'weight': 0.38633958397933643},
#  {'source': 'cluster_5', 'sink': 'paradileptus', 'weight': 0.3859062694283703},
#  {'source': 'cv_o2_depth', 'sink': 'cv_o2_day', 'weight': 0.3857203218296193},
#  {'source': 'ciliate', 'sink': 'ceratium', 'weight': 0.3848068397029265},
#  {'source': 'mean_ph', 'sink': 'mean_epi_temp', 'weight': -0.3847566140398274},
#  {'source': 'cluster_6', 'sink': 'cluster_4', 'weight': 0.3842352785745072},
#  {'source': 'ceratium',
#   'sink': 'keratella_cochlearis',
#   'weight': 0.3839837717325913},
#  {'source': 'cv_temp_day', 'sink': 'cv_schmidt', 'weight': 0.3836202872318931},
#  {'source': 'temp_mean', 'sink': 'mean_par', 'weight': 0.38343756400024376},
#  {'source': 'windspeed_max',
#   'sink': 'atmospheric_pressure_mean',
#   'weight': -0.38290857898236663},
#  {'source': 'cv_ph_depth',
#   'sink': 'mean_oxycline_depth',
#   'weight': -0.3827295960476736},
#  {'source': 'cluster_1', 'sink': 'diatom', 'weight': 0.3823028485820904},
#  {'source': 'mean_condF', 'sink': 'mean_temp', 'weight': 0.38158128750944975},
#  {'source': 'mean_schmidt',
#   'sink': 'cv_o2_depth',
#   'weight': 0.38154864501452634},
#  {'source': 'TN', 'sink': 'Nitrat', 'weight': 0.38116454611136336},
#  {'source': 'cluster_4', 'sink': 'cluster_8', 'weight': 0.3811085495804099},
#  {'source': 'mean_o2ppm',
#   'sink': 'mean_oxycline_depth',
#   'weight': 0.38088062164133774},
#  {'source': 'mean_condF', 'sink': 'temp_min', 'weight': 0.3808786640791021},
#  {'source': 'cv_ph_depth', 'sink': 'mean_temp', 'weight': 0.3807192547113688},
#  {'source': 'cluster_7', 'sink': 'diatom', 'weight': 0.3805506339764248},
#  {'source': 'mean_condF', 'sink': 'Ammonium', 'weight': -0.3797770816548169},
#  {'source': 'TP', 'sink': 'Nitrat', 'weight': -0.3790692865766059},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'cv_temp_day',
#   'weight': -0.3790243150716487},
#  {'source': 'paradileptus',
#   'sink': 'brachionus',
#   'weight': 0.3789923876074195},
#  {'source': 'mean_epi_temp',
#   'sink': 'cv_epi_temp',
#   'weight': 0.37888999062639167},
#  {'source': 'Ammonium', 'sink': 'ciliate', 'weight': -0.3783845062706932},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'temp_min',
#   'weight': -0.3778860497709281},
#  {'source': 'TP', 'sink': 'temp_min', 'weight': -0.377533297683748},
#  {'source': 'mean_temp', 'sink': 'temp_mean', 'weight': 0.37746751555707586},
#  {'source': 'ml_irradiance',
#   'sink': 'mean_global_radiation',
#   'weight': 0.37736036653381955},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'rotifers',
#   'weight': -0.3758713073301354},
#  {'source': 'oP', 'sink': 'mean_o2', 'weight': -0.3754379964664797},
#  {'source': 'cv_epi_temp',
#   'sink': 'cv_condF_day',
#   'weight': 0.3734257436964024},
#  {'source': 'cv_condF_day',
#   'sink': 'cv_condF_depth',
#   'weight': 0.3734160409839428},
#  {'source': 'cv_temp_depth',
#   'sink': 'cv_par_depth',
#   'weight': 0.37334143662577485},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'mean_mixed_layer_depth',
#   'weight': 0.3731130408711331},
#  {'source': 'ceratium', 'sink': 'cluster_6', 'weight': 0.3729104175519986},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'temp_min',
#   'weight': -0.3728799069710459},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'cv_temp_depth',
#   'weight': -0.37218992618819685},
#  {'source': 'mean_temp', 'sink': 'cv_ph_depth', 'weight': 0.37193489802174},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'mean_global_radiation',
#   'weight': -0.3717663843924882},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'cv_condF_depth',
#   'weight': -0.3717239555904407},
#  {'source': 'ceratium', 'sink': 'cluster_8', 'weight': 0.37090925159727667},
#  {'source': 'mean_cloud_cover',
#   'sink': 'precipitation_tot',
#   'weight': 0.3703497064195226},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'precipitation_tot',
#   'weight': 0.37026113723100085},
#  {'source': 'month', 'sink': 'cv_temp_depth', 'weight': -0.37015491583213905},
#  {'source': 'mean_schmidt',
#   'sink': 'cv_o2ppm_depth',
#   'weight': 0.369843724773303},
#  {'source': 'mean_cloud_cover',
#   'sink': 'cluster_3',
#   'weight': -0.36969958708157985},
#  {'source': 'brachionus',
#   'sink': 'paradileptus',
#   'weight': 0.36927630870976835},
#  {'source': 'Nitrit', 'sink': 'month', 'weight': 0.36883219554894225},
#  {'source': 'mean_schmidt', 'sink': 'TP', 'weight': -0.3681828287756322},
#  {'source': 'diatom', 'sink': 'cluster_6', 'weight': 0.368043903427011},
#  {'source': 'ceratium', 'sink': 'asterionella', 'weight': 0.3677031958030338},
#  {'source': 'mean_chla', 'sink': 'cluster_2', 'weight': 0.36750526921852555},
#  {'source': 'precipitation_tot',
#   'sink': 'rel_air_humidity_max',
#   'weight': 0.3674564819796886},
#  {'source': 'Ammonium',
#   'sink': 'cv_condF_depth',
#   'weight': -0.36739552885179366},
#  {'source': 'ceratium', 'sink': 'brachionus', 'weight': 0.36627685785597097},
#  {'source': 'cv_oxycline_depth',
#   'sink': 'mean_o2ppm',
#   'weight': -0.3660925974019147},
#  {'source': 'cv_o2_depth',
#   'sink': 'cv_chla_depth',
#   'weight': 0.36608583141489964},
#  {'source': 'cv_o2_depth',
#   'sink': 'mean_oxycline_depth',
#   'weight': -0.36598289519143323},
#  {'source': 'cluster_8', 'sink': 'ciliate', 'weight': 0.3656601962686328},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'mean_turb',
#   'weight': -0.3654845638032375},
#  {'source': 'keratella_quadrata',
#   'sink': 'dinobryon',
#   'weight': 0.365402422299221},
#  {'source': 'cluster_3', 'sink': 'cv_ph_depth', 'weight': 0.36529678250770875},
#  {'source': 'mean_cloud_cover',
#   'sink': 'atmospheric_pressure_max',
#   'weight': -0.365168501124036},
#  {'source': 'kellikottia', 'sink': 'mean_temp', 'weight': -0.362699592211486},
#  {'source': 'temp_mean',
#   'sink': 'ml_irradiance',
#   'weight': 0.3623237780804303},
#  {'source': 'cv_temp_depth',
#   'sink': 'cv_condF_day',
#   'weight': 0.361821327618251},
#  {'source': 'TP', 'sink': 'mean_o2ppm', 'weight': -0.36179728957881807},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'mean_chla',
#   'weight': -0.36115646084886255},
#  {'source': 'TP', 'sink': 'temp_max', 'weight': -0.36093620509840085},
#  {'source': 'oP', 'sink': 'temp_mean', 'weight': -0.3605900206562561},
#  {'source': 'cv_temp_depth', 'sink': 'temp_max', 'weight': 0.3599273175493085},
#  {'source': 'Ammonium', 'sink': 'dinobryon', 'weight': -0.3597982961870584},
#  {'source': 'temp_mean',
#   'sink': 'mean_mixed_layer_depth',
#   'weight': -0.35919122771223794},
#  {'source': 'mean_o2', 'sink': 'TP', 'weight': -0.3591671426433161},
#  {'source': 'month', 'sink': 'diatom', 'weight': -0.3591497107864429},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'cv_o2_depth',
#   'weight': -0.35885333672866565},
#  {'source': 'ml_irradiance',
#   'sink': 'rel_air_humidity_min',
#   'weight': -0.35884593607955817},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'cv_par_depth',
#   'weight': -0.3587417758718807},
#  {'source': 'cv_temp_depth', 'sink': 'mean_par', 'weight': 0.3582371951462501},
#  {'source': 'mean_global_radiation',
#   'sink': 'temp_mean',
#   'weight': 0.35807981293677377},
#  {'source': 'precipitation_tot',
#   'sink': 'atmospheric_pressure_min',
#   'weight': -0.3574649727427658},
#  {'source': 'mean_temp', 'sink': 'oP', 'weight': -0.35744472024015767},
#  {'source': 'cv_temp_depth',
#   'sink': 'temp_mean',
#   'weight': 0.35693050414359795},
#  {'source': 'temp_max', 'sink': 'mean_schmidt', 'weight': 0.35577842240538265},
#  {'source': 'oP', 'sink': 'temp_max', 'weight': -0.3552118679148201},
#  {'source': 'cluster_6', 'sink': 'fragilaria', 'weight': 0.35485084026276587},
#  {'source': 'mean_chla', 'sink': 'cluster_7', 'weight': 0.3547527101475766},
#  {'source': 'temp_max', 'sink': 'mean_epi_temp', 'weight': 0.3546390729184866},
#  {'source': 'mean_cloud_cover',
#   'sink': 'nauplius',
#   'weight': -0.35348593115560045},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'mean_par',
#   'weight': -0.3534854891406614},
#  {'source': 'cv_condF_depth',
#   'sink': 'cv_chla_depth',
#   'weight': 0.3532846498552256},
#  {'source': 'rotifers', 'sink': 'brachionus', 'weight': 0.3529195579170784},
#  {'source': 'Ammonium', 'sink': 'rotifers', 'weight': -0.3529022311980965},
#  {'source': 'Ammonium',
#   'sink': 'mean_global_radiation',
#   'weight': -0.3526193119355902},
#  {'source': 'asterionella',
#   'sink': 'cluster_8',
#   'weight': 0.35253715762019405},
#  {'source': 'oP', 'sink': 'cv_condF_depth', 'weight': -0.3523938716784079},
#  {'source': 'kellikottia',
#   'sink': 'mean_epi_temp',
#   'weight': -0.35181455991449134},
#  {'source': 'month', 'sink': 'mean_chla', 'weight': -0.3518029197582445},
#  {'source': 'mean_o2', 'sink': 'Ammonium', 'weight': -0.3515951066089987},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'cv_epi_temp',
#   'weight': -0.3512798812838705},
#  {'source': 'mean_ph',
#   'sink': 'mean_oxycline_depth',
#   'weight': 0.35095882624279456},
#  {'source': 'kellikottia',
#   'sink': 'mean_schmidt',
#   'weight': -0.3508819503052379},
#  {'source': 'rel_air_humidity_max',
#   'sink': 'mean_par',
#   'weight': -0.3504262117546835},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'cv_epi_temp',
#   'weight': -0.3503921231478929},
#  {'source': 'cluster_2', 'sink': 'mean_chla', 'weight': 0.34855165534126503},
#  {'source': 'cluster_7', 'sink': 'cluster_4', 'weight': 0.3483261639733733},
#  {'source': 'cluster_2', 'sink': 'cv_ph_depth', 'weight': 0.34827593531463713},
#  {'source': 'mean_ph', 'sink': 'cv_chla_depth', 'weight': -0.3478658208099459},
#  {'source': 'ml_irradiance',
#   'sink': 'mean_cloud_cover',
#   'weight': -0.3462316457777878},
#  {'source': 'temp_mean',
#   'sink': 'mean_cloud_cover',
#   'weight': -0.3461141392268085},
#  {'source': 'cv_o2ppm_day',
#   'sink': 'cv_o2ppm_depth',
#   'weight': 0.3459826074573668},
#  {'source': 'Ammonium', 'sink': 'cluster_5', 'weight': -0.34593028288890887},
#  {'source': 'cv_condF_depth',
#   'sink': 'mean_thermocline_depth',
#   'weight': -0.3454046876524332},
#  {'source': 'mean_condF',
#   'sink': 'mean_schmidt',
#   'weight': 0.3449426975786006},
#  {'source': 'cv_oxycline_depth',
#   'sink': 'mean_oxycline_depth',
#   'weight': -0.34464039978437067},
#  {'source': 'diaphanosoma', 'sink': 'daphnia', 'weight': 0.34424319941732373},
#  {'source': 'cluster_2', 'sink': 'cluster_4', 'weight': 0.34372943232288483},
#  {'source': 'mean_condF', 'sink': 'temp_mean', 'weight': 0.34357265684322547},
#  {'source': 'mean_schmidt',
#   'sink': 'Ammonium',
#   'weight': -0.34318438470953605},
#  {'source': 'cluster_5', 'sink': 'brachionus', 'weight': 0.3431646803172497},
#  {'source': 'trichocerca', 'sink': 'cluster_1', 'weight': 0.34278787891349977},
#  {'source': 'precipitation_tot',
#   'sink': 'atmospheric_pressure_mean',
#   'weight': -0.3426122154717023},
#  {'source': 'mean_temp', 'sink': 'Ammonium', 'weight': -0.34261178687987387},
#  {'source': 'paradileptus',
#   'sink': 'dinobryon',
#   'weight': 0.34232340685034923},
#  {'source': 'cv_ph_depth',
#   'sink': 'mean_schmidt',
#   'weight': 0.3420342628964226},
#  {'source': 'mean_epi_temp',
#   'sink': 'cv_o2_depth',
#   'weight': 0.3417031731462735},
#  {'source': 'cluster_8', 'sink': 'diatom', 'weight': 0.34168346891827706},
#  {'source': 'cv_temp_day', 'sink': 'cv_thermo', 'weight': 0.3415822876541797},
#  {'source': 'cluster_8', 'sink': 'cluster_7', 'weight': 0.3415627125774028},
#  {'source': 'diaphanosoma', 'sink': 'cyclops', 'weight': 0.34123180165282924},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'cv_epi_temp',
#   'weight': -0.3410758756174333},
#  {'source': 'oP', 'sink': 'temp_min', 'weight': -0.34071653614793657},
#  {'source': 'cv_ph_depth',
#   'sink': 'mean_epi_temp',
#   'weight': 0.34064412889145856},
#  {'source': 'ml_irradiance',
#   'sink': 'rel_air_humidity_mean',
#   'weight': -0.34033594041335025},
#  {'source': 'diatom', 'sink': 'fragilaria', 'weight': 0.3401899261421607},
#  {'source': 'temp_mean',
#   'sink': 'mean_thermocline_depth',
#   'weight': -0.33980615380615486},
#  {'source': 'cv_temp_depth', 'sink': 'temp_min', 'weight': 0.3397742512331296},
#  {'source': 'cyclops', 'sink': 'diaphanosoma', 'weight': 0.3397555719150754},
#  {'source': 'cv_ph_depth', 'sink': 'cluster_1', 'weight': 0.3395563396316694},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'month',
#   'weight': 0.33934028126015603},
#  {'source': 'cv_mixed_layer_depth',
#   'sink': 'temp_max',
#   'weight': -0.3391177437262213},
#  {'source': 'cv_ph_depth', 'sink': 'mean_ph', 'weight': -0.3388911264237466},
#  {'source': 'windspeed_mean',
#   'sink': 'cluster_1',
#   'weight': -0.33866255435566006},
#  {'source': 'diatom', 'sink': 'ceratium', 'weight': 0.33861659386295395},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'cluster_3',
#   'weight': -0.3385844717794224},
#  {'source': 'atmospheric_pressure_mean',
#   'sink': 'windspeed_max',
#   'weight': -0.33789605277249785},
#  {'source': 'Nitrit', 'sink': 'mean_chla', 'weight': -0.337817592686948},
#  {'source': 'temp_max',
#   'sink': 'mean_mixed_layer_depth',
#   'weight': -0.3377396490915625},
#  {'source': 'Ammonium', 'sink': 'cluster_6', 'weight': -0.3368516395210422},
#  {'source': 'keratella_cochlearis',
#   'sink': 'cluster_5',
#   'weight': 0.3367575081981814},
#  {'source': 'mean_temp', 'sink': 'cv_o2_depth', 'weight': 0.3366101340054302},
#  {'source': 'mean_ph', 'sink': 'ciliate', 'weight': -0.33638421652733225},
#  {'source': 'oP', 'sink': 'diaphanosoma', 'weight': -0.3359945249346616},
#  {'source': 'mean_ph', 'sink': 'mean_condF', 'weight': -0.3359836706393639},
#  {'source': 'cv_temp_depth',
#   'sink': 'mean_condF',
#   'weight': 0.3359369420279509},
#  {'source': 'cv_condF_depth',
#   'sink': 'mean_mixed_layer_depth',
#   'weight': -0.3354749066239673},
#  {'source': 'asterionella',
#   'sink': 'fragilaria',
#   'weight': 0.3353266693002408},
#  {'source': 'brachionus', 'sink': 'ceratium', 'weight': 0.33528288787878274},
#  {'source': 'temp_max',
#   'sink': 'rel_air_humidity_max',
#   'weight': -0.3351752462665317},
#  {'source': 'cv_ph_depth',
#   'sink': 'cv_temp_depth',
#   'weight': 0.33516250309112017},
#  {'source': 'mean_epi_temp',
#   'sink': 'cv_o2ppm_depth',
#   'weight': 0.3350598802994772},
#  {'source': 'cv_o2ppm_depth',
#   'sink': 'mean_oxycline_depth',
#   'weight': -0.33358098415714355},
#  {'source': 'cv_temp_depth',
#   'sink': 'cv_o2ppm_depth',
#   'weight': 0.3335348312856041},
#  {'source': 'oP', 'sink': 'cyclops', 'weight': -0.33328771230066884},
#  {'source': 'cv_o2_day',
#   'sink': 'cv_o2ppm_depth',
#   'weight': 0.3329133651230377},
#  {'source': 'cluster_1', 'sink': 'cluster_5', 'weight': 0.33268659222186403},
# ...
#  {'source': 'mean_schmidt', 'sink': 'mean_par', 'weight': 0.2859073693007777},
#  {'source': 'keratella_cochlearis',
#   'sink': 'uroglena',
#   'weight': 0.285892176438605},
#  {'source': 'asterionella', 'sink': 'ceratium', 'weight': 0.2858799474975761},
#  {'source': 'keratella_cochlearis',
#   'sink': 'rotifers',
#   'weight': 0.28558202610877004},
#  {'source': 'cv_ph_depth', 'sink': 'temp_mean', 'weight': 0.2854780919811575},
#  {'source': 'asplanchna', 'sink': 'synchaeta', 'weight': 0.28541469022933386},
#  {'source': 'cluster_4',
#   'sink': 'keratella_cochlearis',
#   'weight': 0.2849939112134645},
#  {'source': 'Ammonium', 'sink': 'mean_turb', 'weight': -0.28470543264274184},
#  {'source': 'dinobryon', 'sink': 'ceratium', 'weight': 0.28446344157139275},
#  {'source': 'uroglena', 'sink': 'paradileptus', 'weight': 0.2842677685014619},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'sunshine_duration',
#   'weight': -0.28413954425263627},
#  {'source': 'windspeed_mean',
#   'sink': 'cv_o2ppm_depth',
#   'weight': -0.28400045863639706},
#  {'source': 'atmospheric_pressure_min',
#   'sink': 'wind_direction_mean',
#   'weight': -0.283978335789622},
#  {'source': 'precipitation_tot',
#   'sink': 'windspeed_max',
#   'weight': 0.2838784318431163},
#  {'source': 'cv_ph_depth',
#   'sink': 'cv_chla_depth',
#   'weight': 0.28384685403169657},
#  {'source': 'rotifers', 'sink': 'trichocerca', 'weight': 0.28365249248530305},
#  {'source': 'cv_mixed_layer_depth',
#   'sink': 'cyclops',
#   'weight': -0.28337249110450424},
#  {'source': 'mean_o2', 'sink': 'mean_temp', 'weight': 0.28324989955433966},
#  {'source': 'mean_epi_temp',
#   'sink': 'cv_condF_depth',
#   'weight': 0.28288470116298203},
#  {'source': 'cv_mixed_layer_depth',
#   'sink': 'temp_min',
#   'weight': -0.28264648354274896},
#  {'source': 'rel_air_humidity_max',
#   'sink': 'cv_epi_temp',
#   'weight': -0.28258842978140664},
#  {'source': 'mean_ph', 'sink': 'temp_min', 'weight': -0.2825705687861551},
#  {'source': 'cv_epi_temp',
#   'sink': 'ml_irradiance',
#   'weight': 0.28238659316399106},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'uroglena',
#   'weight': -0.28221089611226546},
#  {'source': 'cluster_7', 'sink': 'cluster_3', 'weight': 0.28210613710858606},
#  {'source': 'cluster_3', 'sink': 'Ammonium', 'weight': -0.2816724664169446},
#  {'source': 'year', 'sink': 'mean_epi_temp', 'weight': -0.28161653740041154},
#  {'source': 'rotifers', 'sink': 'nauplius', 'weight': 0.28155713693579026},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'rel_air_humidity_min',
#   'weight': 0.2815425186389517},
#  {'source': 'mean_global_radiation',
#   'sink': 'atmospheric_pressure_min',
#   'weight': 0.28149975106887093},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'TP',
#   'weight': 0.281373977524965},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'rel_air_humidity_mean',
#   'weight': 0.2812398370857206},
#  {'source': 'mean_cloud_cover',
#   'sink': 'cv_o2_depth',
#   'weight': -0.2811021692674175},
#  {'source': 'cyclops', 'sink': 'bosmina', 'weight': 0.28089180838438316},
#  {'source': 'diatom_chain',
#   'sink': 'mean_condF',
#   'weight': -0.2808573430102339},
#  {'source': 'mean_condF', 'sink': 'mean_o2', 'weight': 0.2806589367455988},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'cluster_7',
#   'weight': -0.2801293534741767},
#  {'source': 'mean_par', 'sink': 'temp_max', 'weight': 0.2800215392799679},
#  {'source': 'rotifers',
#   'sink': 'keratella_quadrata',
#   'weight': 0.27999976303416263},
#  {'source': 'diatom', 'sink': 'TP', 'weight': 0.27962277694603155},
#  {'source': 'cv_par_depth',
#   'sink': 'precipitation_tot',
#   'weight': -0.27953297540786726},
#  {'source': 'mean_schmidt',
#   'sink': 'mean_mixed_layer_depth',
#   'weight': -0.27939025305417664},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'cv_condF_depth',
#   'weight': -0.2793382712190442},
#  {'source': 'cluster_3', 'sink': 'trichocerca', 'weight': 0.27931344884818926},
#  {'source': 'cv_mixed_layer_depth',
#   'sink': 'diaphanosoma',
#   'weight': -0.27925100288281574},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'cv_o2_day',
#   'weight': -0.2791861561208043},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'mean_o2ppm',
#   'weight': -0.2791640544017461},
#  {'source': 'wind_direction_mean',
#   'sink': 'mean_cloud_cover',
#   'weight': 0.2789618692884274},
#  {'source': 'windspeed_mean',
#   'sink': 'mean_epi_temp',
#   'weight': -0.27878381593880824},
#  {'source': 'temp_mean', 'sink': 'mean_o2', 'weight': 0.2781615440190852},
#  {'source': 'Nitrit', 'sink': 'mean_par', 'weight': -0.27771632210654484},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'cv_o2ppm_day',
#   'weight': -0.2775326884990877},
#  {'source': 'cv_temp_depth',
#   'sink': 'mean_global_radiation',
#   'weight': 0.2774207757227901},
#  {'source': 'rel_air_humidity_max',
#   'sink': 'ml_irradiance',
#   'weight': -0.27741529701832435},
#  {'source': 'trichocerca',
#   'sink': 'diatom_chain',
#   'weight': 0.27728821032392836},
#  {'source': 'year', 'sink': 'mean_temp', 'weight': -0.2771842476044472},
#  {'source': 'month',
#   'sink': 'mean_global_radiation',
#   'weight': -0.2768967858944637},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'diatom',
#   'weight': -0.2766005410654695},
#  {'source': 'keratella_cochlearis',
#   'sink': 'conochilus',
#   'weight': 0.27654297872540334},
#  {'source': 'cv_condF_depth',
#   'sink': 'cv_temp_day',
#   'weight': 0.27651414206357405},
#  {'source': 'cv_condF_depth',
#   'sink': 'cv_epi_temp',
#   'weight': 0.2764611895917326},
#  {'source': 'cv_temp_day', 'sink': 'cluster_6', 'weight': -0.2762273428630388},
#  {'source': 'ceratium', 'sink': 'aphanizomenon', 'weight': 0.2761911663325062},
#  {'source': 'month', 'sink': 'nauplius', 'weight': -0.27611869021961977},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'mean_condF',
#   'weight': -0.275909526770958},
#  {'source': 'cv_thermo', 'sink': 'cv_condF_day', 'weight': 0.2758554758178728},
#  {'source': 'synchaeta', 'sink': 'mean_temp', 'weight': -0.27579218498267727},
#  {'source': 'cluster_8',
#   'sink': 'paradileptus',
#   'weight': 0.27574770221033745},
#  {'source': 'oP', 'sink': 'mean_o2ppm', 'weight': -0.27558357988249826},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'cluster_4',
#   'weight': -0.2755526515370302},
#  {'source': 'cluster_2',
#   'sink': 'rel_air_humidity_min',
#   'weight': -0.2755462566154423},
#  {'source': 'diatom', 'sink': 'cluster_3', 'weight': 0.27527941025035896},
#  {'source': 'Ammonium', 'sink': 'nauplius', 'weight': -0.2752086059941876},
#  {'source': 'keratella_cochlearis',
#   'sink': 'trichocerca',
#   'weight': 0.2750791585975114},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'ciliate',
#   'weight': -0.27501744070150486},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'rel_air_humidity_min',
#   'weight': 0.27500716299916395},
#  {'source': 'sunshine_duration',
#   'sink': 'atmospheric_pressure_max',
#   'weight': 0.2747608077846463},
#  {'source': 'trichocerca', 'sink': 'dinobryon', 'weight': 0.27475994573521617},
#  {'source': 'windspeed_max',
#   'sink': 'cluster_2',
#   'weight': -0.27467426418124996},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'cluster_7',
#   'weight': -0.27451513247658527},
#  {'source': 'Nitrit', 'sink': 'Nitrat', 'weight': -0.27413687183019164},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'cv_chla_depth',
#   'weight': -0.2740261994151337},
#  {'source': 'mean_cloud_cover',
#   'sink': 'mean_o2ppm',
#   'weight': -0.2739821515449063},
#  {'source': 'cluster_1', 'sink': 'temp_max', 'weight': 0.2739333822643135},
#  {'source': 'mean_global_radiation',
#   'sink': 'cv_temp_depth',
#   'weight': 0.2737834812161249},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'cluster_4',
#   'weight': -0.27376030334133084},
#  {'source': 'dinobryon', 'sink': 'trichocerca', 'weight': 0.27359302544016467},
#  {'source': 'oP', 'sink': 'cv_condF_day', 'weight': -0.2735680172503948},
#  {'source': 'mean_cloud_cover',
#   'sink': 'temp_min',
#   'weight': -0.27352083317592174},
#  {'source': 'cluster_2', 'sink': 'temp_max', 'weight': 0.27349422974304977},
#  {'source': 'windspeed_mean',
#   'sink': 'cluster_3',
#   'weight': -0.2733828545630923},
#  {'source': 'wind_direction_mean',
#   'sink': 'sunshine_duration',
#   'weight': -0.27314785240571826},
#  {'source': 'temp_mean', 'sink': 'cv_ph_depth', 'weight': 0.2729335949419578},
#  {'source': 'windspeed_mean',
#   'sink': 'mean_temp',
#   'weight': -0.27289541113682725},
#  {'source': 'temp_min', 'sink': 'cv_condF_depth', 'weight': 0.27255127080055},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'mean_epi_temp',
#   'weight': -0.272294085862204},
#  {'source': 'mean_cloud_cover',
#   'sink': 'mean_schmidt',
#   'weight': -0.2719307918563987},
#  {'source': 'windspeed_max',
#   'sink': 'cv_ph_depth',
#   'weight': -0.2719001380201751},
#  {'source': 'mean_par', 'sink': 'cv_temp_depth', 'weight': 0.2718251668265572},
#  {'source': 'keratella_cochlearis',
#   'sink': 'cluster_6',
#   'weight': 0.2717643307484116},
#  {'source': 'mean_temp', 'sink': 'cv_epi_temp', 'weight': 0.27174092421010915},
#  {'source': 'cluster_4', 'sink': 'cv_ph_depth', 'weight': 0.27172557537591646},
#  {'source': 'cv_o2_depth',
#   'sink': 'mean_epi_temp',
#   'weight': 0.27150737855302937},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'ciliate',
#   'weight': -0.27146685813331417},
#  {'source': 'cv_mixed_layer_depth',
#   'sink': 'sunshine_duration',
#   'weight': -0.2714150645095836},
#  {'source': 'Nitrit', 'sink': 'cluster_7', 'weight': -0.27139444828304166},
#  {'source': 'cv_turb_depth',
#   'sink': 'cv_turb_day',
#   'weight': 0.27136217798538365},
#  {'source': 'windspeed_mean',
#   'sink': 'atmospheric_pressure_mean',
#   'weight': -0.2713178646821436},
#  {'source': 'paradileptus', 'sink': 'diatom', 'weight': 0.27116607678790716},
#  {'source': 'sunshine_duration',
#   'sink': 'temp_mean',
#   'weight': 0.27115702518484425},
#  {'source': 'mean_chla', 'sink': 'ceratium', 'weight': 0.27111415685793655},
#  {'source': 'cluster_1',
#   'sink': 'mean_oxycline_depth',
#   'weight': -0.2710961594564715},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'mean_chla',
#   'weight': -0.2709014215544722},
#  {'source': 'wind_direction_mean',
#   'sink': 'mean_global_radiation',
#   'weight': -0.2707900423625292},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'rotifers',
#   'weight': -0.2707413819036029},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'mean_condF',
#   'weight': -0.2706436463648529},
#  {'source': 'synchaeta',
#   'sink': 'mean_epi_temp',
#   'weight': -0.27036261303276304},
#  {'source': 'temp_max', 'sink': 'cv_epi_temp', 'weight': 0.27034572544516206},
#  {'source': 'mean_par',
#   'sink': 'rel_air_humidity_max',
#   'weight': -0.27032637645852864},
#  {'source': 'cv_par_depth',
#   'sink': 'mean_mixed_layer_depth',
#   'weight': -0.27020146855256827},
#  {'source': 'ceratium', 'sink': 'fragilaria', 'weight': 0.2700199038299524},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'cv_condF_depth',
#   'weight': -0.2700114085316028},
#  {'source': 'oP', 'sink': 'dinobryon', 'weight': -0.26996972051238377},
#  {'source': 'windspeed_mean',
#   'sink': 'temp_max',
#   'weight': -0.2697995947749974},
#  {'source': 'mean_epi_temp',
#   'sink': 'kellikottia',
#   'weight': -0.26979212281942505},
#  {'source': 'conochilus',
#   'sink': 'mean_epi_temp',
#   'weight': -0.26978804533865897},
#  {'source': 'temp_min', 'sink': 'cv_epi_temp', 'weight': 0.2693042544506474},
#  {'source': 'cluster_8', 'sink': 'cluster_4', 'weight': 0.2690419226672528},
#  {'source': 'mean_temp',
#   'sink': 'cv_temp_depth',
#   'weight': 0.26895524593807374},
#  {'source': 'mean_o2', 'sink': 'temp_mean', 'weight': 0.2687931408914273},
#  {'source': 'cyclops', 'sink': 'rotifers', 'weight': 0.2687353988096248},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'mean_o2',
#   'weight': -0.26872296636049803},
#  {'source': 'dinobryon', 'sink': 'conochilus', 'weight': 0.2686319661296764},
#  {'source': 'cluster_3', 'sink': 'cluster_5', 'weight': 0.26857049738129707},
#  {'source': 'windspeed_mean',
#   'sink': 'mean_schmidt',
#   'weight': -0.26852206141206314},
#  {'source': 'cv_schmidt',
#   'sink': 'mean_epi_temp',
#   'weight': -0.2685161274396953},
#  {'source': 'rel_air_humidity_max',
#   'sink': 'nauplius',
#   'weight': -0.2675543559058568},
#  {'source': 'Ammonium', 'sink': 'brachionus', 'weight': -0.26746427959752206},
#  {'source': 'cv_o2_depth', 'sink': 'mean_ph', 'weight': -0.2674088581863376},
#  {'source': 'windspeed_max',
#   'sink': 'precipitation_tot',
#   'weight': 0.2673798173153567},
#  {'source': 'cluster_4', 'sink': 'trichocerca', 'weight': 0.26737667634326395},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'mean_ph',
#   'weight': 0.2671265569551038},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'sunshine_duration',
#   'weight': -0.26711659201208915},
#  {'source': 'paradileptus',
#   'sink': 'cluster_6',
#   'weight': 0.26700841348161947},
#  {'source': 'cv_mixed_layer_depth',
#   'sink': 'mean_cloud_cover',
#   'weight': 0.26692209215543256},
#  {'source': 'atmospheric_pressure_min',
#   'sink': 'windspeed_mean',
#   'weight': -0.26687639813173153},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'Ammonium',
#   'weight': 0.26658553881110164},
#  {'source': 'cv_temp_depth', 'sink': 'diatom', 'weight': -0.26640967113590375},
#  {'source': 'mean_thermocline_depth',
#   'sink': 'trichocerca',
#   'weight': -0.26623272643332296},
#  {'source': 'cluster_2',
#   'sink': 'rel_air_humidity_mean',
#   'weight': -0.26597925866489436},
#  {'source': 'cv_mixed_layer_depth',
#   'sink': 'mean_global_radiation',
#   'weight': -0.2659546459466149},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'rotifers',
#   'weight': -0.2658780106471771},
#  {'source': 'mean_par',
#   'sink': 'precipitation_tot',
#   'weight': -0.26560724110281886},
#  {'source': 'cluster_2',
#   'sink': 'mean_mixed_layer_depth',
#   'weight': -0.26558353471195895},
#  {'source': 'cluster_6', 'sink': 'dinobryon', 'weight': 0.26553633848271596},
#  {'source': 'mean_mixed_layer_depth',
#   'sink': 'cv_temp_day',
#   'weight': -0.2654256815697132},
#  {'source': 'windspeed_max',
#   'sink': 'cv_o2_depth',
#   'weight': -0.26529582579869737},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'cyclops',
#   'weight': -0.2652383046002888},
#  {'source': 'oP', 'sink': 'brachionus', 'weight': -0.26521343221115196},
#  {'source': 'diatom', 'sink': 'kellikottia', 'weight': 0.26514750098264633},
#  {'source': 'mean_chla', 'sink': 'trichocerca', 'weight': 0.26507791659298696},
#  {'source': 'cluster_1', 'sink': 'temp_mean', 'weight': 0.26507704609054444},
#  {'source': 'mean_epi_temp',
#   'sink': 'cv_par_depth',
#   'weight': 0.26481327720016873},
#  {'source': 'oP', 'sink': 'cluster_7', 'weight': -0.26467333505781143},
#  {'source': 'diatom_chain',
#   'sink': 'temp_mean',
#   'weight': -0.2645536087278473},
#  {'source': 'conochilus', 'sink': 'mean_temp', 'weight': -0.2644686315912762},
#  {'source': 'cv_temp_day', 'sink': 'diatom', 'weight': -0.2644214522298838},
#  {'source': 'temp_mean', 'sink': 'Ammonium', 'weight': -0.2644001918706252},
#  {'source': 'cv_turb_day',
#   'sink': 'cv_turb_depth',
#   'weight': 0.26436645930020986},
#  {'source': 'month', 'sink': 'cv_condF_depth', 'weight': -0.26419968554809886},
#  {'source': 'temp_mean', 'sink': 'cv_o2_depth', 'weight': 0.26411586453324337},
#  {'source': 'mean_global_radiation',
#   'sink': 'atmospheric_pressure_mean',
#   'weight': 0.2641015638370827},
#  {'source': 'oP',
#   'sink': 'mean_oxycline_depth',
#   'weight': 0.26402309667025037},
#  {'source': 'ml_irradiance',
#   'sink': 'cluster_5',
#   'weight': -0.2638194311272559},
#  {'source': 'mean_oxycline_depth',
#   'sink': 'diatom',
#   'weight': -0.2634928277815137},
#  {'source': 'rel_air_humidity_min',
#   'sink': 'cluster_6',
#   'weight': -0.26337933448646345},
#  {'source': 'rel_air_humidity_mean',
#   'sink': 'Ammonium',
#   'weight': 0.2633293409710058},
#  {'source': 'mean_schmidt',
#   'sink': 'kellikottia',
#   'weight': -0.2632184840090702},
#  {'source': 'fragilaria', 'sink': 'cluster_8', 'weight': 0.2632120308191244},
#  {'source': 'year', 'sink': 'mean_condF', 'weight': -0.26302224149537856},
#  {'source': 'cv_schmidt',
#   'sink': 'cv_ph_depth',
#   'weight': -0.2628941689661062},
#  {'source': 'atmospheric_pressure_max',
#   'sink': 'mean_cloud_cover',
#   'weight': -0.26276478972377576},
#  {'source': 'cluster_2',
#   'sink': 'mean_global_radiation',
#   'weight': 0.26258506042221086},
#  ...]

# %%
def build_PMFG(sorted_edges, nb_nodes):
    PMFG = nx.Graph()
    for edge in sorted_edges:
        if edge['weight']<0:
            PMFG.add_edge(edge['source'], edge['sink'],weight=-15*edge['weight'],color='red')
        else:
            PMFG.add_edge(edge['source'], edge['sink'],weight= 15*edge['weight'],color='blue')
        planar,_ = nx.check_planarity(PMFG, counterexample=False)
        if not planar:
            PMFG.remove_edge(edge['source'], edge['sink'])
            
        if len(PMFG.edges()) == 3*(nb_nodes-2):
            break
    
    return PMFG
PMFG = build_PMFG(sorted_edges,size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <module>
#      13             break
#      15     return PMFG
# ---> 16 PMFG = build_PMFG(sorted_edges,size)
#
# Input In [19], in build_PMFG(sorted_edges, nb_nodes)
#       1 def build_PMFG(sorted_edges, nb_nodes):
# ----> 2     PMFG = nx.Graph()
#       3     for edge in sorted_edges:
#       4         if edge['weight']<0:
#
# NameError: name 'nx' is not defined

# %%
PMFG
PMFG_disp = Network(height='600px', width='800px', bgcolor='#FFFFFF', font_color='black',
                      directed=True,layout=False)
PMFG_disp.from_nx(PMFG)

# %%
for node in PMFG_disp.nodes:
    key = node['id']
    if key in taxa_keys:
        color = 'lime'
    elif key in cluster_keys: 
        color = 'green'
    elif key in water_keys:
        color = 'blue'
    elif key in meteo_keys:
        color = 'cyan'
    elif key in nut_keys:
        color = 'red'
    elif key in phys_keys:
        color = 'yellow'
    else:
        color = 'purple'
    node['color']=color

# %%
#PMFG_disp.show_buttons()
PMFG_disp.show('PMFG.html')

# %% [markdown]
# # Attention Matrix

# %%
#load the adjacency matrix:
file_att = 'adj_att.pickle'
with open(file_att, 'rb') as f:
    adj= pickle.load(f)
file_name = 'name.pickle'
with open(file_name, 'rb') as f:
    names = pickle.load(f)

# %%
plt.imshow(adj)

# %%
size = adj.shape[0]
edges=[]
for idx1 in range(size):
    for idx2 in range(size):
        if idx1 != idx2:
            edge = {'source': names[idx1], 'sink':names[idx2], 'weight':adj[idx1,idx2]}
            edges.append(edge)

# %%
sorted_edges = sorted(edges,key= lambda x: np.abs(x['weight']),reverse=True)

# %%
PMFG = build_PMFG(sorted_edges,size)

# %%
PMFG
PMFG_disp = Network(height='600px', width='800px', bgcolor='#FFFFFF', font_color='black',
                      directed=True,layout=False)
PMFG_disp.from_nx(PMFG)

# %%
for node in PMFG_disp.nodes:
    key = node['id']
    if key in taxa_keys:
        color = 'lime'
    elif key in cluster_keys: 
        color = 'green'
    elif key in water_keys:
        color = 'blue'
    elif key in meteo_keys:
        color = 'cyan'
    elif key in nut_keys:
        color = 'red'
    elif key in phys_keys:
        color = 'yellow'
    else:
        color = 'purple'
    node['color']=color

# %%
PMFG_disp.show('PMFG_att.html')
