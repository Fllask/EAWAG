# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as  np
from scipy import signal
import scipy
from pydlm import dlm, autoReg

# %% [markdown]
# ## Aim
# Build a Dynamic linear model of the data in the form:
#
#
# $y_{t+1} = b_t+\phi_t y_t+\epsilon_t$
#
# $b_t = b_{t-1} + \omega_{b,t-1}$
#
# $\phi_t = \phi_t + \omega_{\phi, t-1}$
#
# Where $y_t$ is the observable at time t, $b_t$ is its true level, and $\epsilon_t, \omega_{b,t}$ and $\omega_{\phi,t}$ are different sources of random noise, respectively responding to the distributions $\mathcal{N}(0,\sigma_y^2), \mathcal{N}(0,\sigma_b^2)$ and $\mathcal{N}(0,\sigma_\phi^2)$

# %%
data_path = "..\\Datasets\\Forecasting_aqua\\data_h_rolling_interpolated.csv"
format = "%d/%m/%Y"
df = pd.read_csv(data_path,index_col='Datetime')
df.index = pd.to_datetime(df.index)

# %% [markdown]
# Start with an example serie

# %%
y = df['mean_chla_depth'].dropna().to_numpy()

# %%
def

# %%
plt.plot(y)

# %%
myDLM = dlm(y)
myDLM += autoReg(discount=0.99, name='model', w=1e7)

# %%
myDLM.ls()
# Out:
# There is no static component.
#
# There is no dynamic component.
#
# The automatic components are
# model (dimension = 2)

# %%
myDLM.fit()
# Out:
# Initializing models...
# Initialization finished.
# Starting forward filtering...
# Forward filtering completed.
# Starting backward smoothing...
# Backward smoothing completed.

# %%
myDLM.plot()
# Out:
# C:\Users\valla\Anaconda3\lib\site-packages\pydlm\plot\dlmPlot.py:519: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(str(size[0]) + str(size[1]) + str(location))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [67], in <module>
# ----> 1 myDLM.plot()
#
# File ~\Anaconda3\lib\site-packages\pydlm\dlm.py:1027, in dlm.plot(self, name)
#    1021         dlmPlot.plotInOneFigure(time=time,
#    1022                                 data=self.data,
#    1023                                 result=self.result,
#    1024                                 options=self.options)
#    1025     # otherwise, we plot in multiple figures
#    1026     else:
# -> 1027         dlmPlot.plotInMultipleFigure(time=time,
#    1028                                      data=self.data,
#    1029                                      result=self.result,
#    1030                                      options=self.options)
#    1032 # plot the component after filtering
#    1033 elif self._checkComponent(name):
#    1034     # create the data for ploting
#
# File ~\Anaconda3\lib\site-packages\pydlm\plot\dlmPlot.py:194, in plotInMultipleFigure(time, data, result, options)
#     187     plotData(time=time[start:end],
#     188              data=to1dArray(result.smoothedObs),
#     189              showDataPoint=options.showFittedPoint,
#     190              color=options.smoothedColor,
#     191              label='smoothed series')
#     193     if options.showConfidenceInterval:
# --> 194         upper, lower = getInterval(result.smoothedObs[start:end],
#     195                                    result.smoothedObsVar[start:end],
#     196                                    p=options.confidence)
#     197         plotInterval(time=time[start:end],
#     198                      upper=to1dArray(upper), lower=to1dArray(lower),
#     199                      intervalType=options.intervalType,
#     200                      color=options.smoothedColor)
#     201 plt.legend(loc='best', shadow=True)
#
# File ~\Anaconda3\lib\site-packages\pydlm\base\tools.py:75, in getInterval(means, var, p)
#      73 lower = [0] * len(means)
#      74 for i in range(0, len(means)):
# ---> 75     upper[i] = means[i] + alpha * math.sqrt(var[i])
#      76     lower[i] = means[i] - alpha * math.sqrt(var[i])
#      78 return (upper, lower)
#
# ValueError: math domain error

# %%
(predictMean, predictVar) = myDLM.predictN(N=15, date=10000)

# %%
myDLM.n
# Out:
# 24590

# %%
plt.plot(predictMean)
plt.scatter(range(16),y[999:1015])

# %%
plt.plot(y)

# %%
y
# Out:
# Datetime
# 2019-01-01 00:00:00         NaN
# 2019-01-01 01:00:00         NaN
# 2019-01-01 02:00:00         NaN
# 2019-01-01 03:00:00         NaN
# 2019-01-01 04:00:00         NaN
#                          ...
# 2021-12-31 19:00:00    3.553174
# 2021-12-31 20:00:00    3.553521
# 2021-12-31 21:00:00    3.554561
# 2021-12-31 22:00:00    3.556397
# 2021-12-31 23:00:00    3.559155
# Name: mean_chla_depth, Length: 26304, dtype: float64
